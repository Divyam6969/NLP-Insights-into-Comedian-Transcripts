# %% [markdown]
# # NLP Assignment 2
# Assignment Completed By
# Divyam Malik (102103142)

# %% [markdown]
# ` Data cleaning is a time consuming and unenjoyable task, yet it's a very important one. Keep in mind, "garbage in, garbage out".`

# %% [markdown]
# # Getting The Data

# %% [markdown]
# Got my transcripts for comedians from [Scraps From The Loft](http://scrapsfromtheloft.com).
#
# ### First I took 20 comedians and extracted their transcript using BeautifulSoup Web scrapping:

# %%
# Web scraping, pickle imports
import requests
from bs4 import BeautifulSoup
import pickle

# Scrapes transcript data from scrapsfromtheloft.com
def url_to_transcript(url):
    '''Returns transcript data specifically from scrapsfromtheloft.com.'''
    page = requests.get(url).text
    soup = BeautifulSoup(page, "html.parser")
    text = [p.text for p in soup.find_all("p")]  
    print(url)
    return text

# URLs of transcripts in scope
urls = [
    "https://scrapsfromtheloft.com/comedy/adel-karam-live-from-beirut-transcript/",
    "https://scrapsfromtheloft.com/comedy/amy-schumer-mostly-sex-stuff-2012-full-transcript/",
    "https://scrapsfromtheloft.com/comedy/beth-stelling-girl-daddy-transcript/",
    "https://scrapsfromtheloft.com/comedy/big-jay-oakerson-live-webster-hall-2016-full-transcript/",
    "https://scrapsfromtheloft.com/comedy/chris-rock-selective-outrage-transcript/",
    "https://scrapsfromtheloft.com/comedy/chelsea-handler-evolution-transcript/",
    "https://scrapsfromtheloft.com/comedy/david-cross-making-america-great-again-transcript/",
    "https://scrapsfromtheloft.com/comedy/dave-chappelle-the-dreamer-transcript/",
    "https://scrapsfromtheloft.com/comedy/dylan-moran-off-the-hook-2015-full-transcript/",
    "https://scrapsfromtheloft.com/comedy/george-carlin-indian-drill-sergeant-transcript/",
    "https://scrapsfromtheloft.com/comedy/iliza-shlesinger-unveiled-transcript/",
    "https://scrapsfromtheloft.com/comedy/kevin-hart-zero-fks-given-2020-transcript/",
    "https://scrapsfromtheloft.com/comedy/kevin-james-irregardless-transcript/",
    "https://scrapsfromtheloft.com/comedy/louis-c-k-live-at-the-beacon-theatre-2011-full-transcript/",
    "https://scrapsfromtheloft.com/comedy/matt-rife-matthew-steven-rife-transcript/",
    "https://scrapsfromtheloft.com/comedy/pete-davidson-turbo-fonzarelli-transcript/",
    "https://scrapsfromtheloft.com/comedy/ricky-gervais-england-2-2010-full-transcript/",
    "https://scrapsfromtheloft.com/comedy/sarah-cooper-everythings-fine-transcript/",
    "https://scrapsfromtheloft.com/comedy/tom-segura-ball-hog-transcript/",
    "https://scrapsfromtheloft.com/comedy/trevor-noah-where-was-i-transcript/"
]

# Comedian names
comedians = [
    'adel_karam', 'amy_schumer', 'beth_stelling', 'big_jay_oakerson', 'chris_rock', 
    'chelsea_handler', 'david_cross', 'dave_chappelle', 'dylan_moran', 'george_carlin', 
    'iliza_shlesinger', 'kevin_hart', 'kevin_james', 'louis_c_k', 'matt_rife', 
    'pete_davidson', 'ricky_gervais', 'sarah_cooper', 'tom_segura', 'trevor_noah'
]

# %%
# Actually request transcripts (takes a few minutes to run)
transcripts = [url_to_transcript(u) for u in urls]
# Out:
# https://scrapsfromtheloft.com/comedy/adel-karam-live-from-beirut-transcript/
# https://scrapsfromtheloft.com/comedy/amy-schumer-mostly-sex-stuff-2012-full-transcript/
# https://scrapsfromtheloft.com/comedy/beth-stelling-girl-daddy-transcript/
# https://scrapsfromtheloft.com/comedy/big-jay-oakerson-live-webster-hall-2016-full-transcript/
# https://scrapsfromtheloft.com/comedy/chris-rock-selective-outrage-transcript/
# https://scrapsfromtheloft.com/comedy/chelsea-handler-evolution-transcript/
# https://scrapsfromtheloft.com/comedy/david-cross-making-america-great-again-transcript/
# https://scrapsfromtheloft.com/comedy/dave-chappelle-the-dreamer-transcript/
# https://scrapsfromtheloft.com/comedy/dylan-moran-off-the-hook-2015-full-transcript/
# https://scrapsfromtheloft.com/comedy/george-carlin-indian-drill-sergeant-transcript/
# https://scrapsfromtheloft.com/comedy/iliza-shlesinger-unveiled-transcript/
# https://scrapsfromtheloft.com/comedy/kevin-hart-zero-fks-given-2020-transcript/
# ...

# %%
# Print first 100 words of each comedian
for comedian, transcript in zip(comedians, transcripts):
    print(f"{comedian}:")
    words = transcript[:10]
    print(' '.join(words))
    print("\n")
# Out:
# adel_karam:
# A NETFLIX COMEDY SPECIAL
# Recorded at the Casino du Liban, Beirut Hello. Wow, this is great! This is great! Good evening. Good evening! God rest his soul! Hello there. “Hello.” So bored! How are you all? This is so cool. That much! Hello up there. Good evening! Yeah, I see you. It’s like you’ve arrived from outer space! I want to say thank you for being here. Thank you for traveling all the way from Beirut to be here. Quite a distance. I came on Thursday so I wouldn’t be late. I usually don’t travel for anyone. See how important you are to me? I came on Thursday.
# ...

# %%
transcripts
# Out:
# [['A NETFLIX COMEDY SPECIAL\nRecorded at the Casino du Liban, Beirut',
# ...

# %% [markdown]
# ### Now I have extracted the transcripts from urls using BeautifulSoup

# %%
import pandas as pd
df = pd.DataFrame(transcripts)
df.describe()
# Out:
#                                                       0    \
# count                                                  20
# unique                                                 20
# top     A NETFLIX COMEDY SPECIAL\nRecorded at the Casi...
# freq                                                    1
#
#                                                       1      2    \
# count                                                  20     20
# unique                                                 20     19
# top     Hello. Wow, this is great! This is great! Good...  * * *
# freq                                                    1      2
#
#                                                       3    \
# count                                                  20
# unique                                                 20
# top     I wish we would learn from women… how they kis...
# freq                                                    1
#
# ...

# %%
# Making a new directory to hold the text files
# !mkdir transcripts

# %%
for i, c in enumerate(comedians):
    with open("transcripts/" + c + ".txt", "wb") as file:
        pickle.dump(transcripts[i], file)

# %%
# Load text files in data variable
data = {}
for i, c in enumerate(comedians):
    with open("transcripts/" + c + ".txt", "rb") as file:
        data[c] = pickle.load(file)

# %%
# Double check to make sure data has been loaded properly
data.keys()
# Out:
# dict_keys(['adel_karam', 'amy_schumer', 'beth_stelling', 'big_jay_oakerson', 'chris_rock', 'chelsea_handler', 'david_cross', 'dave_chappelle', 'dylan_moran', 'george_carlin', 'iliza_shlesinger', 'kevin_hart', 'kevin_james', 'louis_c_k', 'matt_rife', 'pete_davidson', 'ricky_gervais', 'sarah_cooper', 'tom_segura', 'trevor_noah'])

# %% [markdown]
# ### Now we will explore what is the structure of our data

# %%
# More checks
data['pete_davidson'][:2]

## since till second column there is name of the standup comedy
# Out:
# ['Pete Davidson: Turbo Fonzarelli (2024)\nReleased date: January 9, 2024 (Netflix)\nRuntime: 56 min',
# ...

# %% [markdown]
# ### So now I have seen that in the first column of data there is name of the standup comedian

# %% [markdown]
# # Cleaning The Data

# %% [markdown]
# When dealing with numerical data, data cleaning often involves removing null values and duplicate data, dealing with outliers, etc. With text data, there are some common data cleaning techniques, which are also known as text pre-processing techniques.
#
# With text data, this cleaning process can go on forever. There's always an exception to every cleaning step. So, we're going to follow the MVP (minimum viable product) approach - start simple and iterate.
# ### Assignment:
# 1. Perform the following data cleaning on transcripts:
# i) Make text all lower case
# ii) Remove punctuation
# iii) Remove numerical values
# iv) Remove common non-sensical text (/n)
# v) Tokenize text
# vi) Remove stop words

# %%
# Let's take a look at our data again
next(iter(data.keys()))
# Out:
# 'adel_karam'

# %%
# Notice that our dictionary is currently in key: comedian, value: list of text format
next(iter(data.values()))
# Out:
# ['A NETFLIX COMEDY SPECIAL\nRecorded at the Casino du Liban, Beirut',
# ...

# %% [markdown]
# ### Since I know our data values are in form of list so Now I would combine them and remove the list so that data_combined is in format of key - value where key will be comedian name and transcript will be whole three columns combined into a single string

# %%
# We are going to change this to key: comedian, value: string format
def combine_text(list_of_text):
    '''Takes a list of text and combines them into one large chunk of text.'''
    combined_text = ' '.join(list_of_text)
    return combined_text

# %%
# Combine it!
data_combined = {key: [combine_text(value)] for (key, value) in data.items()}

# %%

# ...

# %%
# Apply a second round of cleaning
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
# Let's take a look at the updated text
data_clean = pd.DataFrame(data_clean.transcript.apply(round2))
data_clean
# Out:
#                                                                                                                                                              transcript
# adel_karam        a netflix comedy specialrecorded at the casino du liban beirut hello wow this is great this is great good evening good evening god rest his soul h...
# amy_schumer       fuck yeah this is such a big night for you but im celebrating i finally just slept with my highschool crush right thank you thank you but i swear ...
# beth_stelling     beth stellings standup comedy special girl daddy was released on hbo max on august   the show was recorded at the varsity theater in minneapolis m...
# big_jay_oakerson    – lets get you going here hey hey hey hey hey hey hey hey hey   lets go     – yeah right  wow that  that was a lot of bravado for a fat guy whos...
# ...

# %% [markdown]
# ### Now I will remove the special characters like music symbol, etc

# %%
# Function to clean the text further
def clean_text(text):
    # Remove extra spaces
    text = re.sub('[^A-Za-z]+', ' ', text)
    # Remove leading and trailing spaces
    text = text.strip()
    return text

# Apply the clean_text function to the 'Text' column
data_clean.transcript = data_clean.transcript.apply(clean_text)

# Print the cleaned data frame
data_clean
# Out:
#                                                                                                                                                              transcript
# adel_karam        a netflix comedy specialrecorded at the casino du liban beirut hello wow this is great this is great good evening good evening god rest his soul h...
# amy_schumer       fuck yeah this is such a big night for you but im celebrating i finally just slept with my highschool crush right thank you thank you but i swear ...
# beth_stelling     beth stellings standup comedy special girl daddy was released on hbo max on august the show was recorded at the varsity theater in minneapolis min...
# big_jay_oakerson  lets get you going here hey hey hey hey hey hey hey hey hey lets go yeah right wow that that was a lot of bravado for a fat guy whos gonna sit dow...
# ...

# %%
data['adel_karam']
# Out:
# ['A NETFLIX COMEDY SPECIAL\nRecorded at the Casino du Liban, Beirut',
# ...

# %%
data_clean.transcript['pete_davidson']
# Out:
# 'pete davidson turbo fonzarelli released date january netflixruntime min in pete davidson turbo fonzarelli released on january on netflix davidsons standup comedy special captures him at the crossroads of turning reflecting on his journey he humorously acknowledges the necessity to leave hard drugs behind his routine includes comical anecdotes about ketamine escapades and inventing a fictitious italian sleep aid called melatone as well as recounting awkward moments like being high at aretha franklins funeral davidson doesnt shy away from critiquing apples rental service and openly discusses his mothers midlife crisis and his futile efforts to nudge her back into the dating world davidsons comedic style marked by selfmockery and bursts of unfiltered truthfulness ventures into both contentious and darker subjects with ease he openly discusses his battles with drugs the challenges of fame and mental health issues the special is a blend of humor and poignant reflection showcasing davidso
# ...

# %% [markdown]
# ### I would also remove \t \r as I can see it in all my columns

# %%
# Function to clean \r the text further
def clean_r_text(text):
    # Remove extra spaces
    text = re.sub('\r','', text)
    # Remove leading and trailing spaces
    text = text.strip()
    return text

# Function to clean \t the text further
def clean_t_text(text):
    # Remove extra spaces
    text = re.sub('\t','', text)
    # Remove leading and trailing spaces
    text = text.strip()
    return text

# Apply the clean_text function to the 'Text' column
data_clean.transcript = data_clean.transcript.apply(clean_r_text)

# Apply the clean_text function to the 'Text' column
data_clean.transcript = data_clean.transcript.apply(clean_t_text)

# Print the cleaned data frame
data_clean
# Out:
#                                                                                                                                                              transcript
# adel_karam        a netflix comedy specialrecorded at the casino du liban beirut hello wow this is great this is great good evening good evening god rest his soul h...
# amy_schumer       fuck yeah this is such a big night for you but im celebrating i finally just slept with my highschool crush right thank you thank you but i swear ...
# beth_stelling     beth stellings standup comedy special girl daddy was released on hbo max on august the show was recorded at the varsity theater in minneapolis min...
# big_jay_oakerson  lets get you going here hey hey hey hey hey hey hey hey hey lets go yeah right wow that that was a lot of bravado for a fat guy whos gonna sit dow...
# ...

# %%
data_clean.transcript['dylan_moran'][:2000]
# Out:
# 'ladies and gentlemen will you please welcome to the stage mr dylan moran hey hello thank you hello thank you very much for coming out thank you for leaving your computer screens and all the arguments you were refining at home i am very glad you came um now you people all of you here are the survivors as far as i am concerned you are the people who are tough enough to live in london i didnt quite make it i tried it some time ago but you know you need a lot of grit a lot of gumption youve seen people who wimp out they move to kent or whatever and they still think that theyre sort of you know in the mix and theyre not you know that theyre finished theyre not even human beings youre glad to see them go thats it you didnt have what it takes you couldnt handle the irony before lunch jazzercise for dinner didnt have that thing in you that makes you hungry that gives you what you need to live in a paper cup at the bottom of somebody elses garden in balham you gotta have that thing twelve hu
# ...

# %%
data_clean.transcript['pete_davidson'][-1000:]
# Out:
# 'eeks spread and show your asshole yeah all we gotta do is pull up we gon have all the bitches all you gotta do is say its up you gon have our attention dont be that so i dont kick it less its bout some business your email address will not be published required fields are marked name email website dusty slay shares humorous tales from his life work and southern roots at knoxvilles bijou theatre blending selfdeprecation with lighthearted critique jack whitehall settle down explore humor life insights and cultural observations in british comedian jack whitehalls latest comedy special morans standup navigates lifes absurdities and human flaws with sharp wit blending cynicism with whimsy to reflect on existence in a rapidly changing world kevin james standup comedy special irregardless offers a humorous look at aging technology parenting and marriage enter your email i accept the privacy policy scraps from the loft all rights reserved get the best articles once a week directly to your in
# ...

# %%
data_clean.transcript['adel_karam'][-1000:]
# Out:
# ' to dedicate each show to my father he left us years ago and i really love him very much i really do and i want to say something dad through netflix dad i dedicate my show to you wait dad give my love to edward your email address will not be published required fields are marked name email website dusty slay shares humorous tales from his life work and southern roots at knoxvilles bijou theatre blending selfdeprecation with lighthearted critique jack whitehall settle down explore humor life insights and cultural observations in british comedian jack whitehalls latest comedy special morans standup navigates lifes absurdities and human flaws with sharp wit blending cynicism with whimsy to reflect on existence in a rapidly changing world kevin james standup comedy special irregardless offers a humorous look at aging technology parenting and marriage enter your email i accept the privacy policy scraps from the loft all rights reserved get the best articles once a week directly to your in
# ...

# %% [markdown]
# ### As I can see every transcript has " scraps from the loft all rights reserved" written in the end so I would remove it

# %%
# Function to clean the text further
def clean_lastKa_text(text):
    # Remove extra spaces
    text = re.sub('scraps from the loft all rights reserved', '', text)
    # Remove leading and trailing spaces
    text = text.strip()
    return text

# Apply the clean_text function to the 'Text' column
data_clean.transcript = data_clean.transcript.apply(clean_lastKa_text)

# Print the cleaned data frame
data_clean
# Out:
#                                                                                                                                                              transcript
# adel_karam        a netflix comedy specialrecorded at the casino du liban beirut hello wow this is great this is great good evening good evening god rest his soul h...
# amy_schumer       fuck yeah this is such a big night for you but im celebrating i finally just slept with my highschool crush right thank you thank you but i swear ...

# ...

# %%
# Let's pickle it for later use
data_df.to_pickle("corpus.pkl")

# %% [markdown]
# ### Document-Term Matrix: Example

# %% [markdown]
# For many of the techniques we'll be using in future assignment, the text must be tokenized, meaning broken down into smaller pieces. The most common tokenization technique is to break down text into words. We can do this using scikit-learn's ` CountVectorizer `, where every row will represent a different document and every column will represent a different word.
#
# In addition, with ` CountVectorizer `, we can remove stop words. Stop words are common words that add no additional meaning to text such as 'a', 'the', etc.

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data_clean.transcript)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_dtm.index = data_clean.index
data_dtm
# Out:
#                   aah  ab  abandon  abandoned  abbas  abducted  abduction  \
# adel_karam          0   0        0          0      2         0          0
# amy_schumer         1   0        0          0      0         0          0
# beth_stelling       0   0        0          0      0         0          0
# big_jay_oakerson    0   0        0          3      0         0          0
# chelsea_handler     0   0        0          0      0         0          0
# chris_rock          0   0        0          0      0         0          0
# dave_chappelle      1   0        0          0      0         0          0
# david_cross         0   0        0          0      0         0          0
# dylan_moran         0   1        0          0      0         0          0
# george_carlin       0   0        0          0      0         0          0
# iliza_shlesinger    0   0        0          0      0         0          0
# kevin_hart          3   0        0          0      0         0          0
# ...

# %%
# Let's pickle it for later use
data_dtm.to_pickle("dtm.pkl")

# %%
# Let's also pickle the cleaned data (before we put it in document-term matrix format) and the CountVectorizer object
data_clean.to_pickle('data_clean.pkl')
pickle.dump(cv, open("cv.pkl", "wb"))

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english', ngram_range=(3,3), min_df=2, max_df=.8) ## will remove common words like and is etc
data_cv = cv.fit_transform(data_clean.transcript)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_dtm.index = data_clean.index
data_dtm
# Out:
#                   act like im  adulthood fame personal  anthem dont know  \
# adel_karam                  0                        0                 0
# amy_schumer                 1                        0                 0
# beth_stelling               0                        0                 0
# big_jay_oakerson            0                        0                 0
# chelsea_handler             1                        0                 0
# chris_rock                  0                        0                 0
# dave_chappelle              0                        0                 0
# david_cross                 0                        0                 0
# dylan_moran                 0                        0                 1
# george_carlin               0                        0                 0
# iliza_shlesinger            0                        0                 0
# kevin_hart                  0                        0                 0
# ...

# %%
### Now after doing the sum of all words i can see what is the maximum number of trigram occuring 

# Find the total count for each n-gram across all comedians
ngram_totals = data_dtm.sum()

# Find the top 3 n-grams with the highest total count
top_ngrams = ngram_totals.nlargest(3)

# Extract the corresponding n-grams
top_ngrams_list = top_ngrams.index.tolist()

# Print the sorted n-grams along with their total counts
for ngram in sorted(top_ngrams_list):
    print(f"{ngram}: {top_ngrams[ngram]}")
# Out:
# like dont know: 19
# right right right: 21
# tell dont want: 23

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english', ngram_range=(40, 100), min_df=2, max_df=0.8) ## will remove common words like and is etc
data_cv = cv.fit_transform(data_clean.transcript)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_dtm.index = data_clean.index
data_dtm
# Out:
#                   night email address published required fields marked email website dusty slay shares humorous tales life work southern roots knoxvilles bijou theatre blending selfdeprecation lighthearted critique jack whitehall settle explore humor life insights cultural observations british comedian jack whitehalls latest comedy  \
# adel_karam                                                                                                                                                            0
# amy_schumer                                                                                                                                                           0
# beth_stelling                                                                                                                                                         0
# ...

# %%
data['pete_davidson']
# Out:
# ['Pete Davidson: Turbo Fonzarelli (2024)\nReleased date: January 9, 2024 (Netflix)\nRuntime: 56 min',
# ...

# %% [markdown]
# ##### So Now I can see this sentences
# "your email address will not be published required fields are marked name email website dusty slay shares humorous tales from his life work and southern roots at knoxvilles bijou theatre blending selfdeprecation with lighthearted critique jack whitehall settle down explore humor life insights and cultural observations in british comedian jack whitehalls latest comedy special navigates lifes absurdities and human flaws with sharp wit blending cynicism with whimsy to reflect on existence in a rapidly changing world kevin james standup comedy special irregardless offers a humorous look at aging technology parenting and marriage enter your email i accept the privacy policy get the best articles once a week directly to your inbox"

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english', ngram_range=(60, 100), min_df=2, max_df=0.8) ## will remove common words like and is etc
data_cv = cv.fit_transform(data_clean.transcript)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_dtm.index = data_clean.index
data_dtm

# %%
import re

def cleaningAfterVectorizing(text):
    # Remove specific phrases
    phrases_to_remove = [
        'your email address will not be published required fields are marked name email website dusty slay shares humorous tales from his life work and southern roots at knoxvilles bijou theatre blending selfdeprecation with lighthearted critique jack whitehall settle down explore humor life insights and cultural observations in british comedian jack whitehalls latest comedy special morans standup navigates lifes absurdities and human flaws with sharp wit blending cynicism with whimsy to reflect on existence in a rapidly changing world kevin james standup comedy special irregardless offers a humorous look at aging technology parenting and marriage enter your email i accept the privacy policy get the best articles once a week directly to your inbox'
    ]

    for phrase in phrases_to_remove:
        text = re.sub(phrase, ' ', text)

    # Remove extra spaces
    text = re.sub('\s+', ' ', text).strip()

    return text

# Apply the cleaning function to the entire 'transcript' column
data_clean['transcript'] = data_clean['transcript'].apply(cleaningAfterVectorizing)

# %%
data_clean.transcript['pete_davidson']

# %%
data_clean.transcript['trevor_noah']

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english', ngram_range=(60, 100), min_df=2, max_df=0.8) ## will remove common words like and is etc
data_cv = cv.fit_transform(data_clean.transcript)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_dtm.index = data_clean.index
data_dtm

# %% [markdown]
# #### So I can't find ngram(60,120) so it means now its cleaned :)

# %% [markdown]
# ### So now I can see that I removed the text that was common in all comedians and that was wrongly extracted by Beautiful soup

# %% [markdown]
# ## Additional Assignments:

# %% [markdown]
# 1. Can you add an additional regular expression to the clean_text_round2 function to further clean the text?
# 2. Play around with CountVectorizer's parameters. What is ngram_range? What is min_df and max_df?

# %% [markdown]
# ### Ans 1)
#
# Yes I used few extra data cleaning techniques like
#
# 1) I removed "© scraps from the loft all rights reserved" from the end of every transcript
#
# 2) as well as removed the special music symbol "♪" and "\t \r" characters from the string also removed the extra special characters using text = re.sub('[^A-Za-z]+', ' ', text)"
#
# 3) I removed the repeated line after seeing it from ngram_range(60,120) "address published required fields marked email website kevin james standup comedy special irregardless offers humorous look aging technology parenting marriage pete davidsons standup special turbo fonzarelli blends selfdeprecation honesty tackling adulthood fame personal challenges humor irish comedian david nihill humorously explores identity immigration irishlatino parallels blending personal anecdotes history matthew rifes special blends edgy humor personal stories touching relationships identity societal norms ending tribute late grandfather"
#
# ### Ans 2)
# 1) In this question I printed most occuring n-gram(of size 3) after doing the column sum and there's a crash between 'white people love and "like dont know"
#
# 2) I used ngram_range(60,120) to remove the repeated line "your email address will not be published required fields are marked name email website kevin james standup comedy special irregardless offers a humorous look at aging technology parenting and marriage pete davidsons standup special turbo fonzarelli blends selfdeprecation and honesty tackling adulthood fame and personal challenges with humor irish comedian david nihill humorously explores identity immigration and irishlatino parallels blending personal anecdotes with history matthew rifes special blends edgy humor with personal stories touching on relationships identity and societal norms ending with a tribute to his late grandfather" as it was very common in document matrix and it was also wrongly extracted by beautiful soup on further analysis

# %%
# ngram_range=(1, 2): The ngram_range parameter is set to (1, 2), meaning that both unigrams (single words) and bigrams (two consecutive words) will be considered. This allows capturing not only individual words but also pairs of words that frequently occur together.

# min_df=2: The min_df parameter is set to 2, indicating that a term (word or n-gram) must appear in at least 2 documents to be included in the vocabulary. Terms with lower document frequency will be excluded.

# max_df=0.8: The max_df parameter is set to 0.8, meaning that a term should not appear in more than 80% of the documents. Terms with a higher document frequency will be excluded. This helps in filtering out very common terms that may not provide much discriminatory power.
