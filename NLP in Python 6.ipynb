# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd
data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                          transcript
# adel_karam        A NETFLIX COMEDY SPECIAL\nRecorded at the Casi...
# amy_schumer       Fuck, yeah! This is such a big night for you. ...
# beth_stelling     Beth Stelling’s stand-up comedy special, “Girl...
# big_jay_oakerson  [crowd cheering] [heavy rock music] – Let’s ge...
# chelsea_handler   Join me in welcoming the author of six number ...
# chris_rock        [slow instrumental music playing] [funk drums ...
# dave_chappelle    “The Dreamer,” which was shot in Chappelle’s h...
# david_cross       David Cross: Making America Great Again! is a ...
# dylan_moran       Ladies and gentlemen, will you please welcome ...
# george_carlin     In 1965 “The Indian Sergeant,” was emerging as...
# iliza_shlesinger  Thank you, Nashville! Thank you. So this year ...
# kevin_hart        Streaming on Netflix from November 17, 2020   ...
# kevin_james       Kevin James: Irregardless (2024) In Kevin Jame...
# louis_c_k         [indistinct chatter] — Louis! — Louis! [indist...
# matt_rife         In his second hour-long comedy special, “Matth...
# pete_davidson     Pete Davidson: Turbo Fonzarelli (2024)\nReleas...
# ricky_gervais     Recorded before a live audience at the Chicago...
# sarah_cooper      [anthemic classical music playing] [narrator] ...
# tom_segura        [crowd cheering, applauding] [whistling] [whoo...
# trevor_noah       [lively music playing] [announcer] Detroit, gi...

# %%
chris_rock = data.transcript.loc['chris_rock']
chris_rock[:200]
# Out:
# '[slow instrumental music playing] [funk drums playing] [indistinct chatter] [man] Let’s go! [hip-hop music playing] [audience cheering] [Chris Rock] She said, “$300, I’ll do anything you want.” I said'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
chris_dict = markov_chain(chris_rock)
chris_dict
# Out:
# {'[slow': ['instrumental'],
#  'instrumental': ['music'],
#  'music': ['playing]', 'playing]', 'playing]', 'playing]'],
#  'playing]': ['[funk',
#   '[indistinct',
#   '[audience',
#   '[female',
#   '[audience',
#   'Your'],
#  '[funk': ['drums'],
#  'drums': ['playing]'],
#  '[indistinct': ['chatter]'],
#  'chatter]': ['[man]'],
#  '[man]': ['Let’s', 'Whoo!'],
#  'Let’s': ['go!', 'see', 'just'],
#  'go!': ['[hip-hop'],
#  '[hip-hop': ['music', 'music', 'music'],
#  '[audience': ['cheering]',
#   'laughing]',
#   'cheering]',
#   'cheering]',
#   'continue',
#   'cheers',
#   'cheering]',
#   'laughing]',
#   'applauding]',
#   'laughing',
#   'laughing]',
#   'cheer',
#   'cheering]',
#   'cheering]',
#   'laughs]',
#   'cheering',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'cheering',
#   'cheering]',
#   'laughing',
#   'cheering]',
#   'applauding]',
#   'cheering]',
#   'laughs]',
#   'laughs]',
#   'cheering]',
#   'cheering]',
#   'cheering]',
#   'cheering]',
#   'cheering',
#   'continue'],
#  'cheering]': ['[Chris',
#   '[hip-hop',
#   '[audience',
#   '[Chris',
#   'That’s',
#   'Okay?',
#   'Absolutely',
#   'Okay?',
#   'Here’s',
#   'My',
#   'I',
#   'Pookie,',
#   'I',
#   'That’s',
#   '[“N*gga'],
#  '[Chris': ['Rock]', 'Rock]', 'Rock'],
#  'Rock]': ['She', 'What’s'],
#  'She': ['said,',
#   'said,',
#   'just',
#   'don’t',
#   'lets',
#   'came',
#   'is',
#   'got',
#   'is',
#   'could',
#   'is',
#   'hurt',
#   'fucking',
#   'started',
#   'started',
#   'said,'],
#  'said,': ['“$300,',
#   '“Bitch,',
#   'uh,',
#   '“They’re',
#   '“Not',
#   '“Robert',
#   '“Today,',
#   '“That’s',
#   '“He',
#   'me,'],
#  '“$300,': ['I’ll'],
#  'I’ll': ['do', 'play', 'go,', 'be'],
#  'do': ['anything',
#   'a',
#   'a',
#   'you',
#   'business,',
#   'a',
#   'my',
#   'when',
#   'you',
#   'with',
#   'with',
#   'not',
#   'with',
#   'with',
#   'so',
#   'not',
#   'it',
#   'not',
#   'not',
#   'a',
#   'with',
#   'something',
#   'that',
#   'nothing',
#   'some',
#   'nothing',
#   'nothing'],
#  'anything': ['you', 'to', 'to'],
#  'you': ['want.”',
#   'so',
#   'so',
#   'never',
#   'say.',
#   'write',
#   'a',
#   'go',
#   'are',
#   'to',
#   'with',
#   'feel',
#   'know',
#   'are',
#   'know?',
#   'think',
#   'talking',
#   'did',
#   'do',
#   'about',
#   'how',
#   'work',
#   'talking',
#   'want',
#   'just',
#   'walk.',
#   'get',
#   'don’t',
#   'attention,',
#   'got',
#   'believe–',
#   'see',
#   'see',
#   'don’t',
#   'gotta',
#   'at,',
#   'bring',
#   'wanna',
#   'need',
#   'up',
#   'genius,',
#   'up',
#   'old',
#   'forgot',
#   'know,',
#   'know?',
#   'got',
#   'doing?',
#   'shouldn’t',
#   'go.”',
#   'should',
#   'want.',
#   'should',
#   'get',
#   'can',
#   'have',
#   'should',
#   'can',
#   'something.',
#   'think',
#   'think',
#   'think',
#   'ain’t',
#   'put',
#   'put',
#   'want,',
#   'give',
#   'smiling',
#   'fired,',
#   'to',
#   'to',
#   'should',
#   'them',
#   'about',
#   'were',
#   'needed',
#   'needed',
#   'couldn’t',
#   'had',
#   'know,',
#   '’til',
#   'don’t',
#   'don’t',
#   'know,',
#   'again.',
#   'my',
#   'every',
#   'go',
#   'the',
#   'the',
#   'naked.',
#   'help',
#   'roll',
#   'this',
#   'this',
#   'get',
#   'think',
#   'leaving',
#   'later.”',
#   'come',
#   'to',
#   'gotta',
#   'gotta',
#   'just',
#   'fucking',
#   'can',
#   'want,',
#   'got',
#   'can',
#   'in?',
#   'can',
#   'in',
#   'see',
#   'see',
#   'are',
#   'can’t',
#   'feel?”',
#   'do',
#   'didn’t',
#   'didn’t'],
#  'want.”': ['I'],
#  'I': ['said,',
#   'ain’t',
#   'have',
#   'have',
#   'have',
#   'play',
#   'bumped',
#   'love',
#   'feel',
#   'went',
#   'walk',
#   'don’t',
#   'think',
#   'speak',
#   'say',
#   'do',
#   'do',
#   'do',
#   'get',
#   'not',
#   'say,',
#   'buy',
#   'like',
#   'could',
#   'was',
#   'saw',
#   'saw',
#   'love',
#   'love',
#   'need',
#   'was',
#   'had',
#   'know',
#   'know',
#   'know',
#   'love',
#   'love',
#   'love',
#   'love',
#   'thought',
#   'thought',
#   'thought',
#   'would',
#   'would',
#   'would',
#   'got',
#   'mean,',
#   'actually',
#   'would',
#   'would',
#   'ain’t',
#   'would',
#   'would',
#   'would',
#   'said',
#   'go',
#   'say,',
#   'go',
#   'get',
#   'have',
#   'have',
#   'love',
#   'love',
#   'love',
#   'want',
#   'am',
#   'am',
#   'believe',
#   'believe',
#   'don’t',
#   'pay',
#   'request',
#   'call',
#   'think',
#   'think',
#   'love',
#   'love',
#   'don’t',
#   'don’t',
#   'don’t',
#   'know',
#   'identify',
#   'did',
#   'fucking',
#   'want',
#   'want',
#   'want',
#   'don’t',
#   'remember',
#   'did',
#   'used',
#   'ain’t',
#   'smoked',
#   'was',
#   'thought',
#   'was',
#   'didn’t',
#   'didn’t',
#   'was',
#   'was',
#   'was',
#   'tried',
#   'was',
#   'started',
#   'argued',
#   'lost',
#   'talked',
#   'should',
#   'come',
#   'see',
#   'walk',
#   'kind',
#   'got',
#   'got',
#   'drove',
#   'drove',
#   'was',
#   'need',
#   'went',
#   'didn’t',
#   'was',
#   'act',
#   'didn’t',
#   'was',
#   'had',
#   'had',
#   'have',
#   'mean,',
#   'cannot',
#   'got',
#   'was',
#   'was',
#   'was',
#   'flipped',
#   'was',
#   'want',
#   'will',
#   'might',
#   'know,',
#   'ain’t',
#   'know',
#   'can’t',
#   'fucked,',
#   'know',
#   'ever',
#   'didn’t',
#   'get',
#   'get',
#   'get',
#   'send',
#   'send',
#   'get',
#   'put',
#   'get',
#   'got',
#   'got',
#   'need',
#   'go',
#   'just',
#   'was',
#   'used',
#   'was',
#   'have',
#   'have',
#   'have',
#   'had',
#   'want',
#   'want',
#   'want',
#   'know.',
#   'know',
#   'have',
#   'do',
#   'don’t',
#   'don’t',
#   'do',
#   'got',
#   'got',
#   'got',
#   'couldn’t',
#   'love',
#   'took',
#   'took',
#   'know',
#   'got',
#   'auditioned',
#   'played',
#   'played',
#   'am',
#   'had',
#   'didn’t',
#   'didn’t.',
#   'did',
#   'normally',
#   'have',
#   'was',
#   'tried',
#   'do',
#   'should',
#   'shouldn’t',
#   'do',
#   'finished',
#   'love',
#   'love',
#   'saw',
#   'love',
#   'root',
#   'watch',
#   'got',
#   'was',
#   'accept'],
#  '“Bitch,': ['paint'],
#  'paint': ['my'],
#  'my': ['house.”',
#   'Netflix',
#   'best.',
#   'old',
#   'good',
#   'favorite',
#   'pants',
#   'homework.',
#   'hand',
#   'show.',
#   'father',
#   'father',
#   'father',
#   'father',
#   'brothers',
#   'older',
#   'father',
#   'kids!”',
#   'brother.',
#   'daughters',
#   'daughters',
#   'kids.',
#   'kids,',
#   'kids.',
#   'kids?',
#   'kids',
#   'pronoun',
#   'kids',
#   'kids',
#   'kids',
#   'youngest,',
#   'favorite',
#   'mother,',
#   'brothers,',
#   'mother,',
#   'mother’s',
#   'life.',
#   'kids,',
#   'kids,',
#   'oldest,',
#   'child.',
#   'ex-wife.',
#   'ex-wife',
#   'house.',
#   'daughter',
#   'Black',
#   'child',
#   'child',
#   'God,',
#   'daughter,',
#   'mother',
#   'mother.',
#   'mother.',
#   'mother,',
#   'mother',
#   'life',
#   'girl.',
#   'age,',
#   'roof?”',
#   'dick',
#   'car?”',
#   'money',
#   'ear.',
#   'shirt',
#   'condolences.',
#   'whole',
#   'parents'],
#  'house.”': ['We'],
#  'We': ['don’t',
#   'got',
#   'just',
#   'are',
#   'are',
#   'used',
#   'don’t',
#   'got',
#   'gotta',
#   'gotta',
#   'got',
#   'are',
#   'in',
#   'went',
#   'weren’t',
#   'were',
#   'don’t',
#   'got',
#   'don’t',
#   'all'],
#  'don’t': ['need',
#   'even',
#   'even',
#   'support',
#   'need',
#   'you',
#   'support',
#   'sell',
#   'got',
#   'got',
#   'know',
#   'stop”',
#   'give',
#   'gotta',
#   'want',
#   'give',
#   'like',
#   'like',
#   'like',
#   'even',
#   'know',
#   'play',
#   'even',
#   'have',
#   'even',
#   'even',
#   'make',
#   'want',
#   'even',
#   'have',
#   'work',
#   'need',
#   'need',
#   'know'],
#  'need': ['the',
#   'to',
#   'your',
#   'your',
#   'your',
#   'help,',
#   'is',
#   'to',
#   'a',
#   'to',
#   'a',
#   'you',
#   'you',
#   'my',
#   'a',
#   'you',
#   'another',
#   'it.',
#   'that',
#   'the'],
#  'the': ['death',
#   'tossed',
#   'wrong',
#   'face.',
#   'old',
#   'woke',
#   'wokeness.',
#   'selective',
#   'exact',
#   'kind',
#   'other',
#   'job?”',
#   'job.”',
#   'fuck',
#   'product',
#   'money.”',
#   'mall',
#   'other',
#   'window',
#   'game',
#   'other',
#   'car',
#   'richest',
#   'cum',
#   'moon.',
#   'poor.',
#   'entire',
#   'same',
#   'biggest',
#   'world',
#   'game.',
#   'morning.',
#   'number',
#   'real',
#   'emergency',
#   'country.',
#   'last',
#   'fuck',
#   'country!',
#   'Capitol',
#   'government',
#   'Capitol',
#   'Apes',
#   'fuck?',
#   'country?',
#   'other',
#   'way,',
#   'other',
#   'fuck’s',
#   'show.',
#   'light-skinned',
#   'fucking',
#   'royal',
#   'fuck',
#   'royal',
#   'original',
#   'OGs',
#   'Sugarhill',
#   'hippie,',
#   'hippie-dippie',
#   'Budweiser',
#   'fuck',
#   'baby',
#   'baby’s',
#   'baby',
#   'table?”',
#   'dilemma.',
#   'Statue',
#   'father',
#   'Dream',
#   'Klay',
#   'day',
#   'time',
#   'court,',
#   'sin',
#   'rest',
#   'end',
#   'Kardashians.',
#   'Kardashians.',
#   'Kardashians?',
#   'situation',
#   'Kardashians.',
#   'first',
#   'deal.',
#   'least.',
#   'heels',
#   'wig?',
#   'hair',
#   'voice',
#   'Russians',
#   'country',
#   'world.',
#   'truth…',
#   'country.',
#   'country,',
#   'clinic,',
#   'usual.”',
#   'right',
#   'right',
#   'doctor',
#   'right',
#   'clinic.”',
#   'meanest',
#   'face',
#   'earth.',
#   'most',
#   'worst',
#   'only',
#   'whole',
#   'fuck',
#   'fuck',
#   'womb',
#   'hood.”',
#   'exact',
#   'hood.',
#   'best',
#   'Rock',
#   'teacher',
#   'four',
#   'time,',
#   'Illuminati',
#   'characters,',
#   'characters.',
#   'Devil.',
#   'driver',
#   'way.',
#   'Bronx',
#   'class',
#   'class.',
#   'ones',
#   'good',
#   'fuck',
#   'last',
#   'lawyer,',
#   'lawyer’s',
#   'school.”',
#   'car.',
#   'fucking',
#   'school.',
#   'school',
#   'dean.',
#   'school,',
#   'phone',
#   'news.',
#   'lawyer',
#   'amazing',
#   'coolest',
#   'law',
#   'law',
#   'indignity',
#   'same',
#   'crazy',
#   'amazing',
#   'other',
#   'bed?”',
#   'other',
#   'other',
#   'Netflix',
#   'player,',
#   'game.',
#   'link?”',
#   'link?”',
#   'app',
#   'price',
#   'worst',
#   'worst',
#   'fuck’s',
#   'window',
#   'fuck?',
#   'pussy',
#   'pot',
#   'next',
#   'house,',
#   'mechanic',
#   'car.',
#   'mechanic’s',
#   'mechanic',
#   'power.',
#   'power.',
#   'power.',
#   'power.',
#   'fucking',
#   'pussy',
#   'pussy',
#   'pussy’s',
#   'pussy’s',
#   'pussy’s',
#   'pussy’s',
#   'pussy',
#   'advantages.',
#   'advantages.',
#   'afternoon',
#   'gym,',
#   'afternoon',
#   'yard,',
#   'power,',
#   'smartest',
#   'beauty.',
#   'finest',
#   'power.',
#   'way,',
#   'smoke.',
#   'fucking',
#   'time.”',
#   'same',
#   'fuck,',
#   'fuck',
#   'Internet.',
#   'fuck?',
#   'person',
#   'fuck',
#   'way,',
#   'world',
#   'motherfucker',
#   'Drink',
#   'fuck',
#   'fuck',
#   'fuck?',
#   'Oscars.',
#   'fuck?',
#   'fuck?',
#   'fuck',
#   'fuck,',
#   'Nassau',
#   'privacy',
#   'Loft.',
#   'best'],
#  'death': ['penalty!'],
#  'penalty!': ['We'],
#  'got': ['the',
#   'a',
#   'better',
#   'a',
#   'problems',
#   'ass!',
#   'on',
#   'no',
#   'some',
#   'three',
#   'titties?',
#   'away',
#   'in',
#   'nothing',
#   'no',
#   'the',
#   'to',
#   'to',
#   'it',
#   'fencing',
#   'there,',
#   'busted.',
#   'busted.',
#   'rich-ass',
#   'lawyers.',
#   'lawyers.',
#   'them',
#   'those',
#   'the',
#   'a',
#   'a',
#   'back',
#   'back',
#   'a',
#   'the',
#   'kicked',
#   'kicked',
#   'kicked',
#   'some',
#   'that.',
#   'to',
#   'to',
#   'a',
#   'a',
#   'the',
#   'a',
#   'the',
#   'a',
#   'a',
#   '$35.”',
#   'your',
#   'all',
#   'all',
#   'just',
#   'the',
#   'smacked',
#   'smacked',
#   '“Summertime”',
#   'on',
#   'me',
#   'parents.',
#   'parents.'],
#  'tossed': ['salad'],
#  'salad': ['man!'],
#  'man!': ['‘Cause'],
#  '‘Cause': ['if',
#   'they',
#   'you',
#   'words',
#   'his',
#   'Chyna',
#   'she’s',
#   'even',
#   'you',
#   'they',
#   'I’m',
#   'Ukraine',
#   'I’m',
#   'whenever',
#   'my',
#   'when',
#   'I’m',
#   'on',
#   'there’s',
#   'everybody',
#   'I',
#   'I'],
#  'if': ['a',
#   'somebody',
#   'you',
#   'everybody',
#   'my',
#   'my',
#   'the',
#   'you',
#   'you’re',
#   'you',
#   'you',
#   'you’re',
#   'we',
#   'you’re',
#   'you’re',
#   'I',
#   'I',
#   'she',
#   'she',
#   'Jay-Z'],
#  'a': ['bullet',
#   'payback.',
#   'few',
#   'show.',
#   'show',
#   'brick,',
#   'certain',
#   'gay',
#   'problem',
#   'party.',
#   'new',
#   'safe',
#   'lot',
#   'wire',
#   'phone',
#   'sign',
#   'fuck?”',
#   'commercial',
#   'fuck?”',
#   'Tesla,',
#   'six-month',
#   'pair',
#   'show,',
#   'good',
#   'school.',
#   'show.',
#   'victim.',
#   'victim',
#   'world',
#   'victim.',
#   'Black',
#   'Black',
#   'couple',
#   'shit',
#   'mixed',
#   'commercial',
#   'Japanese',
#   'caterpillar.',
#   'commercial',
#   '“Dogg-age”?',
#   'victim.',
#   'nice',
#   'lot!”',
#   'scientific',
#   'Steph',
#   'Draymond',
#   'hard',
#   'bell',
#   'bell!',
#   'white',
#   'white',
#   'social',
#   'Kardashian.”',
#   'Black',
#   'plate,',
#   'fuck.',
#   'plate,',
#   'valuable',
#   'Black,',
#   'Black,',
#   'very',
#   'woman,',
#   'few',
#   'woman,',
#   'woman,',
#   'game',
#   'Cover',
#   'woman,',
#   'little',
#   'Raiders',
#   'woman,',
#   'problem',
#   'very',
#   'motherfucking',
#   'bad',
#   'more',
#   'women’s',
#   'women’s',
#   'punch',
#   'free',
#   'part',
#   'part',
#   'part',
#   'world',
#   'fuck.',
#   'baby.',
#   'dead',
#   'hit',
#   'baby',
#   'baby',
#   'scholarship.”',
#   'smoothie.”',
#   'public',
#   'school,',
#   'child',
#   'birthday',
#   'lot',
#   'little',
#   'hood,',
#   'lot.',
#   'joint',
#   'lap',
#   'kid,',
#   'church',
#   'church',
#   'bus',
#   'bed',
#   'quarter',
#   'nasty,',
#   'quarter',
#   'ride.”',
#   'senior',
#   'class',
#   'class',
#   'fancy',
#   'fancy',
#   'kid,',
#   'gorilla',
#   'report',
#   'bar,',
#   'lawyer',
#   'lawyer',
#   'lawyer.”',
#   'lawyer,',
#   'lawyer,',
#   'lawyer.',
#   'lawyer.',
#   'lot',
#   'favor.”',
#   'celebrity.',
#   'beautiful',
#   'beautiful',
#   'second.',
#   'little',
#   'little',
#   'Black',
#   'white',
#   'Black',
#   'white',
#   'little',
#   'little',
#   'Black',
#   'vet.',
#   'vet,',
#   'vet.',
#   'fucking',
#   'year,',
#   'plane,',
#   'long',
#   'long',
#   'while.',
#   'woman',
#   'real',
#   'Sunday',
#   'ho.',
#   'ton',
#   'lot',
#   '25-year-old,',
#   'pair',
#   'woman]',
#   'woman]',
#   'pair',
#   '25',
#   '45,',
#   '45,',
#   '45,',
#   'house',
#   'snake?”',
#   '45,',
#   'car',
#   'piece',
#   'good',
#   'good',
#   'Mercedes',
#   '308?',
#   'Tesla',
#   'little',
#   'fucked',
#   'favor.”',
#   'man',
#   'dead',
#   'highway',
#   'supermarket.',
#   'chance',
#   'Wednesday,',
#   'nice',
#   'Whole',
#   'place',
#   'Wednesday,',
#   'billionaire,',
#   'Jay-Z',
#   'year',
#   'victim,',
#   'movie',
#   'movie',
#   'sweater.',
#   'movie.',
#   'piece',
#   'shark.',
#   'bitch.',
#   'bitch.',
#   'bitch.',
#   'bitch.',
#   'fucking',
#   'bitch',
#   'predator.',
#   'bitch.',
#   'fuck?',
#   'fucking',
#   'fucking',
#   'spot,',
#   'spot.',
#   'rapidly',
#   'humorous',
#   'week'],
#  'bullet': ['costs'],
#  'costs': ['$5,000,'],
#  '$5,000,': ['there’ll'],
#  'there’ll': ['be'],
#  'be': ['no',
#   'infamous.',
#   'excellent.',
#   'a',
#   'a',
#   'there',
#   'a',
#   'a',
#   'accepted',
#   'accepted',
#   'accepted',
#   'accepted',
#   'accepted',
#   'accepted',
#   'the',
#   'perfectly',
#   'perfectly',
#   'a',
#   'a',
#   'like,',
#   'the',
#   'able',
#   'at',
#   'lost',
#   'able',
#   'back',
#   'a',
#   'published.'],
#  'no': ['more',
#   'problem',
#   'problem',
#   'more.',
#   'pharmacist',
#   'victim-shaming',
#   'money!',
#   'more',
#   'Black',
#   'idea',
#   'fuss,',
#   'beef',
#   'AC.',
#   'time.”',
#   'idea',
#   'idea',
#   'idea.',
#   'sense.',
#   'idea'],
#  'more': ['innocent',
#   'followers',
#   'white',
#   'than',
#   'nuanced',
#   'abortions',
#   'and',
#   'intimate',
#   'than',
#   'powerful',
#   'powerful,',
#   'powerful',
#   'college',
#   'powerful',
#   'powerful',
#   'than'],
#  'innocent': ['bystanders.'],
#  'bystanders.': ['I'],
#  'ain’t': ['scared',
#   'nobody',
#   'victims.',
#   'us.',
#   'as',
#   'shaking',
#   'never',
#   'never',
#   'take',
#   'it?',
#   'holding',
#   'sexy',
#   'working',
#   'funny',
#   'nothing',
#   'pick'],
#  'scared': ['of', 'of'],
#  'of': ['Al-Qaeda.',
#   'Al-Cracker.',
#   'them',
#   'people',
#   'them',
#   'shit,',
#   'diversity.”',
#   'shit.',
#   'shit,',
#   'shit,',
#   'shit.',
#   'every',
#   '$20',
#   'here.',
#   'record',
#   'office.”',
#   'white',
#   'the',
#   'commercials,',
#   'racism.',
#   'racism.',
#   'racism.',
#   'that',
#   'Black',
#   'Liberty.',
#   'Black',
#   'the',
#   'that',
#   'Black',
#   'helping',
#   'eternity,',
#   'time,',
#   'these',
#   'people,',
#   'them',
#   'that',
#   'reason.',
#   'the',
#   'the',
#   'the',
#   'people',
#   'me…',
#   'me',
#   'me',
#   'their',
#   'that,',
#   'you.',
#   'the',
#   'any',
#   'Black',
#   'my',
#   'her',
#   'course,',
#   'course,',
#   'school.',
#   'their',
#   'her',
#   'snapped.',
#   'parents',
#   'this',
#   'this',
#   'fucking',
#   'school.”',
#   'school',
#   'the',
#   'getting',
#   'the',
#   'love.”',
#   'money,',
#   'people',
#   'shoes.',
#   'a',
#   'shoes.',
#   'shit.',
#   'a',
#   'sexual',
#   'dollars,',
#   'neighborhood',
#   'neighborhood',
#   'the',
#   'all,',
#   'corn',
#   'us',
#   'us.',
#   'here,',
#   'people',
#   'white'],
#  'Al-Qaeda.': ['I’m'],
#  'I’m': ['scared',
#   'all',
#   'all',
#   'talking',
#   'talking',
#   'in',
#   'like,',
#   'looking',
#   'like…',
#   'wearing',
#   'in',
#   'like,',
#   'watching',
#   'like,',
#   'like,',
#   'my',
#   'not',
#   'like,',
#   'like,',
#   'playing,',
#   'like,',
#   'sure',
#   'sure',
#   'an',
#   'sure',
#   'gonna',
#   'an',
#   'like,',
#   'definitely',
#   'on',
#   'trying',
#   'pro-choice.',
#   'pro-choice.',
#   'pro',
#   'pro',
#   'pro',
#   'on',
#   'on',
#   'rich.',
#   'not',
#   'talking',
#   'like,',
#   'like,',
#   'a',
#   'talking',
#   'not',
#   'talking',
#   'single.',
#   'single.',
#   'single',
#   'trying',
#   'loving,',
#   'just',
#   'just',
#   'like,',
#   'all',
#   'doing',
#   'making',
#   'trying',
#   'trying',
#   'not',
#   'in'],
#  'Al-Cracker.': ['You'],
#  'You': ['cannot',
#   'know',
#   'say',
#   'gotta',
#   'know',
#   'gotta',
#   'know',
#   'gotta',
#   'know',
#   'know,',
#   'need',
#   'know',
#   'will',
#   'will',
#   'gotta',
#   'gotta',
#   'gotta',
#   'didn’t',
#   'can’t',
#   'know',
#   'know,',
#   'know',
#   'don’t',
#   'know',
#   'shouldn’t',
#   'know,',
#   'know,',
#   'realize',
#   'look',
#   'know',
#   'can’t',
#   'get',
#   'ever',
#   'know,',
#   'don’t',
#   'don’t',
#   'go,',
#   'go',
#   'go',
#   'go',
#   'don’t',
#   'go',
#   'get',
#   'don’t',
#   'got',
#   'could',
#   'call',
#   'ever',
#   'will',
#   'will',
#   'think',
#   'missed',
#   'missed',
#   'know'],
#  'cannot': ['lend', 'complain,'],
#  'lend': ['money'],
#  'money': ['to', 'on', 'as'],
#  'to': ['people',
#   'crash',
#   'coming',
#   'my',
#   'do',
#   'do',
#   'work,',
#   'say',
#   'get',
#   'a',
#   'cut',
#   'give',
#   'your',
#   'help',
#   'the',
#   'Cherry',
#   'town,',
#   'opioids.',
#   'opioids',
#   'come',
#   'my',
#   'opioids,',
#   'attention.',
#   'want',
#   'attention.',
#   'get',
#   'get',
#   'get',
#   'be',
#   'stab',
#   'get',
#   'be',
#   'ever',
#   'show',
#   'get',
#   'be',
#   'be',
#   'help',
#   'be',
#   'overthrow',
#   'a',
#   'the',
#   'be',
#   'know',
#   'know',
#   'be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'marry',
#   'fix',
#   'free',
#   'free',
#   'free',
#   'Robert',
#   'free',
#   'ever',
#   'believe',
#   'make',
#   'be',
#   'original',
#   'say',
#   'do',
#   'do',
#   'rub',
#   'step',
#   'check',
#   'walk',
#   'him',
#   'a',
#   'the',
#   'live',
#   'kill',
#   'kill',
#   'kill',
#   'kill',
#   'the',
#   'get',
#   'me.',
#   'pay',
#   'save',
#   'teach',
#   'hate.',
#   'raise',
#   'bite',
#   'bite?',
#   'practice',
#   'know',
#   'know',
#   'be',
#   'the',
#   'take',
#   'Disney',
#   'take',
#   'Disney',
#   'meet',
#   'Disney.',
#   'Disney',
#   'Orlando,',
#   'see',
#   'get',
#   'Portugal.',
#   'the',
#   'write',
#   'a',
#   'sneak',
#   'get',
#   'talk',
#   'my',
#   'argue',
#   'the',
#   'some',
#   'get',
#   'choke',
#   'Lola.',
#   'the',
#   'the',
#   'talk.”',
#   'sue',
#   'sue',
#   'get',
#   'kick',
#   'kick',
#   'learn',
#   'happen.',
#   'this',
#   'do',
#   'do',
#   'apply',
#   'another',
#   'write',
#   'apply',
#   'write',
#   'culinary',
#   'go',
#   'a',
#   'go',
#   'a',
#   'go',
#   'a',
#   'a',
#   'a',
#   'go',
#   'Paris,',
#   'culinary',
#   'get',
#   'sleep,',
#   'sleep,',
#   'change',
#   'date.',
#   'fucking',
#   'date,',
#   'date.',
#   'date',
#   '15',
#   'talk',
#   'fuck',
#   'date.',
#   'get',
#   'date',
#   'get',
#   'see',
#   'ever',
#   'the',
#   'pick',
#   'come',
#   'pick',
#   'sweep',
#   'do',
#   'SoulCycle.',
#   'live.',
#   'live.',
#   'live',
#   'live.',
#   'me.',
#   'do',
#   'call',
#   'this',
#   'see',
#   'reflect',
#   'your'],
#  'people': ['you’re',
#   'say.',
#   'getting',
#   'that',
#   'in',
#   'that',
#   'wanna',
#   'more',
#   'love',
#   'and',
#   'here.',
#   'say,',
#   'argue',
#   'without',
#   'are',
#   'get',
#   'I',
#   'think',
#   'like,',
#   'that',
#   'would',
#   'go,'],
#  'you’re': ['fucking.',
#   'gonna',
#   'Black,',
#   'watching',
#   'rich.”',
#   'ever',
#   'biting.',
#   'going',
#   'a',
#   'lucky,',
#   'lucky,',
#   'like…',
#   'in',
#   'in',
#   'in'],
#  'fucking.': ['‘Cause'],
#  'they': ['think',
#   'say.',
#   'just',
#   'just',
#   'get',
#   'don’t',
#   'do.',
#   'need',
#   'need',
#   'ain’t',
#   'run!',
#   'were.”',
#   'accept',
#   'love',
#   'accepted',
#   'could',
#   'give',
#   'have',
#   'always',
#   'still',
#   'still',
#   'curse',
#   'talkin’',
#   'ride',
#   'fence.',
#   'were',
#   'are',
#   'get',
#   'went',
#   'do.',
#   'tried',
#   'got',
#   'got',
#   'don’t',
#   'got',
#   'got',
#   'let',
#   'kicked',
#   'kicked',
#   'gave',
#   'kicked',
#   'won’t',
#   'see',
#   'got',
#   'always',
#   'got',
#   'ever',
#   'always',
#   'say',
#   'will'],
#  'think': ['that',
#   'I’m',
#   'I',
#   'we',
#   'they’re',
#   'they’re',
#   'they’re',
#   'women',
#   'you',
#   'me',
#   'me',
#   'we',
#   'about',
#   'about',
#   'about',
#   'men',
#   'you',
#   'I'],
#  'that': ['sex',
#   'like',
#   'says',
#   'play',
#   'store.',
#   'says,',
#   'shit?',
#   'whistled',
#   'ass.',
#   'have',
#   'know',
#   'they',
#   'shit',
#   'shit',
#   'Kris',
#   'little',
#   'team.',
#   'day',
#   'he',
#   'court…',
#   'day',
#   'was',
#   'if',
#   'we',
#   'shit,',
#   'got',
#   'trans',
#   'first',
#   'has',
#   'big',
#   'vibrates',
#   'some',
#   'they’re',
#   'shit.',
#   'were',
#   'moment,',
#   'shit.',
#   'shit.',
#   'happened.',
#   'had',
#   'you',
#   'shit.',
#   'takes',
#   '45,',
#   '45,',
#   'good',
#   'good',
#   'can',
#   'tour.',
#   'talent',
#   'if',
#   'if',
#   'is',
#   'smoke.',
#   'shit.',
#   'hit',
#   'part?',
#   'really',
#   'I',
#   'shit.',
#   'don’t',
#   'shit',
#   'fucking',
#   'cheated',
#   'make',
#   'shit?',
#   'shit,',
#   'man',
#   'night?”'],
#  'sex': ['is'],
#  'is': ['a',
#   'the',
#   'everybody',
#   'everybody',
#   'full',
#   'attention.',
#   'me',
#   'me,',
#   'showing',
#   'to',
#   'much',
#   'to',
#   'filled',
#   'another',
#   'trying',
#   'she',
#   'she',
#   'she',
#   'she',
#   'really',
#   'there',
#   'like',
#   'a',
#   'united',
#   'clearly',
#   'so',
#   'fucked',
#   'illegal',
#   'killing',
#   'born',
#   'racist.”',
#   'born',
#   'broke.',
#   'in',
#   'a',
#   'going',
#   'so',
#   'one',
#   'so',
#   'amazing.',
#   'going',
#   'good.',
#   'filthy.”',
#   'hard.',
#   'that?',
#   'holding',
#   '10',
#   'what',
#   'like',
#   'nothing',
#   'an',
#   'where',
#   'fucking',
#   'the',
#   'so',
#   'one',
#   'fine,',
#   'so',
#   'so',
#   'not',
#   'significantly',
#   'bigger.',
#   'some'],
#  'payback.': ['We'],
#  'just': ['got',
#   'worked',
#   'wait',
#   'got',
#   'tell',
#   'give',
#   'selling',
#   'sell',
#   'want',
#   'some',
#   'some',
#   'wants',
#   'any',
#   'as',
#   'who',
#   'her',
#   'like',
#   'laughing',
#   'laughing.',
#   'want',
#   'think',
#   'think',
#   'a',
#   'bad.',
#   'wants',
#   'standing',
#   'got',
#   'by',
#   'as',
#   'to'],
#  'few': ['bad', 'episodes'],
#  'bad': ['apples', 'shape', 'place,'],
#  'apples': ['that'],
#  'like': ['to',
#   'the',
#   'to',
#   'the',
#   'a',
#   '“Where',
#   'a',
#   'she',
#   'marrying',
#   'it',
#   'the',
#   'a',
#   'a',
#   'that.',
#   'two',
#   'Wolverine.',
#   'them.',
#   'my',
#   'my',
#   'this.',
#   'normal',
#   'everybody',
#   'any',
#   'I',
#   'I',
#   'all',
#   'these',
#   'your',
#   'your',
#   'your',
#   'your',
#   'to',
#   'spaghetti.',
#   'some',
#   'a',
#   'Pacquiao,',
#   'motherfucking'],
#  'crash': ['into'],
#  'into': ['mountains.', 'the', 'my,', 'the', 'camp,'],
#  'mountains.': ['[audience'],
#  'laughing]': ['[audience', 'Okay?', 'Shit,', 'The', 'Nope.', 'Oh,', '“And'],
#  '[female': ['announcer]'],
#  'announcer]': ['Ladies'],
#  'Ladies': ['and', 'and'],
#  'and': ['gentlemen.',
#   'gentlemen.',
#   'you',
#   'applauding]',
#   'in',
#   'it',
#   'we',
#   'they',
#   'they',
#   'whistling]',
#   'goddamn',
#   'a',
#   'taking',
#   'applauding]',
#   'still',
#   'you',
#   'going,',
#   'I’m',
#   'applauding]',
#   'you',
#   'got',
#   'God',
#   'I',
#   'be',
#   'America',
#   'Democrats',
#   'whistling]',
#   'I',
#   'her',
#   'her',
#   'spoiled.',
#   'applauding]',
#   'I',
#   'their',
#   'they’re',
#   'my',
#   'our',
#   'she’s',
#   'four',
#   'they’re',
#   'get',
#   'we’re',
#   'the',
#   'I',
#   'I',
#   'found',
#   'trying',
#   'trying',
#   'they',
#   'she',
#   'why',
#   'why',
#   'you',
#   'you',
#   'you',
#   'has',
#   'my',
#   'tells',
#   'then',
#   'here’s',
#   'greasy.',
#   'never',
#   'stay',
#   'you',
#   'you’re',
#   'they',
#   'you',
#   'you',
#   'I',
#   'give',
#   'The',
#   'every',
#   'the',
#   'called',
#   'applauding]',
#   'Southern',
#   'cultural',
#   'human',
#   'marriage'],
#  'gentlemen.': ['Ladies', 'Chris'],
#  'Chris': ['Rock!'],
#  'Rock!': ['[audience'],
#  'continue': ['cheering]', 'cheering]'],
#  'What’s': ['up,', 'this'],
#  'up,': ['Baltimore?', 'I’m', 'man.', 'we'],
#  'Baltimore?': ['[audience'],
#  'cheers': ['loudly]'],
#  'loudly]': ['Yes!'],
#  'Yes!': ['Yes,', 'It'],
#  'Yes,': ['yes.', 'they'],
#  'yes.': ['Thank'],
#  'Thank': ['you!', 'you', 'you', 'you.'],
#  'you!': ['Thank'],
#  'so': ['much!',
#   'much',
#   'weird.',
#   'just…',
#   'racist.',
#   'racist.”',
#   'racist!”',
#   'racist.',
#   'hard.',
#   'mean!”',
#   'screwed',
#   'hot,',
#   'funny?”',
#   'funny?”',
#   'serious.',
#   'amazing.',
#   'many',
#   'talented,',
#   'fine',
#   'fine'],
#  'much!': ['Thank'],
#  'much': ['to', 'charity', 'easier', 'better', 'money'],
#  'coming': ['to', 'out'],
#  'Netflix': ['special.', 'special'],
#  'special.': ['Thank'],
#  'you.': ['[audience', 'Now,', 'Everybody’s', 'This', 'That’s'],
#  'That’s': ['right.',
#   'right!',
#   'right.',
#   'what',
#   'right,',
#   'right.',
#   'why',
#   'right.',
#   'right,',
#   'right.',
#   'the',
#   'right.',
#   'right,',
#   'right.',
#   'right.',
#   'right.',
#   'right.',
#   'like',
#   'a',
#   'right.',
#   'right.',
#   'right.',
#   'right.',
#   'another',
#   'way',
#   'right.',
#   'right.',
#   'right.',
#   'right.',
#   'right,',
#   'right.',
#   'right,',
#   'right.',
#   'right.',
#   'just',
#   'right,',
#   'right,',
#   'right.',
#   'right.',
#   'right.',
#   'right.',
#   'right,',
#   'right.',
#   'right.',
#   'right.',
#   'what',
#   'right,',
#   'right,',
#   'right.',
#   'right,',
#   'right,',
#   'right,',
#   'where',
#   'right,',
#   'right,',
#   'how',
#   'what',
#   'how',
#   'what',
#   'why.'],
#  'right.': ['That’s',
#   'You',
#   'Well,',
#   'Like,',
#   'Whenever',
#   'We',
#   'So',
#   'Like',
#   'That’s',
#   'And',
#   'Everybody’s',
#   'She’s',
#   'He',
#   'That’s',
#   'Robert',
#   'And',
#   'The',
#   '“No',
#   'If',
#   'I’m',
#   'Pro-life,',
#   'You’d',
#   'You',
#   'And',
#   'We',
#   'I',
#   'Me,',
#   'My',
#   'I',
#   'You',
#   '‘Cause',
#   'A',
#   'You',
#   'That’s'],
#  'right!': ['Okay.'],
#  'Okay.': ['I’mma'],
#  'I’mma': ['try', 'try…', 'try', 'try'],
#  'try': ['to', 'to', 'my'],
#  'show.': ['[man', '[laughs]', 'That’s', 'Everybody'],
#  '[man': ['shouting', 'whooping]', 'whoops]', 'whoops]', 'whoops]'],
#  'shouting': ['unintelligibly]'],
#  'unintelligibly]': ['I’mma'],
#  'try…': ['N*gga,'],
#  'N*gga,': ['sit', 'you'],
#  'sit': ['down!'],
#  'down!': ['I’mma'],
#  'show': ['tonight', 'your', 'your', 'your'],
#  'tonight': ['without', 'when'],
#  'without': ['offending', 'kids'],
#  'offending': ['nobody,'],
#  'nobody,': ['okay?'],
#  'okay?': ['I’mma',
#   'You',
#   'So,',
#   'Women',
#   'And',
#   '‘Cause',
#   '[audience',
#   'I',
#   'You',
#   'My',
#   'My',
#   'Sometimes',
#   'Either',
#   '‘Cause',
#   '[audience',
#   'Went',
#   'And',
#   'I',
#   'Shit,',
#   'We’re',
#   'Now,',
#   'Get',
#   'Whatever.',
#   'What',
#   'And',
#   'Hit',
#   'I’ve'],
#  'best.': ['You'],
#  'know': ['why?',
#   'who',
#   'what',
#   'anybody',
#   'what',
#   'what',
#   'what',
#   'good',
#   'nothing.',
#   'how',
#   'how',
#   'what',
#   'what',
#   'her',
#   'I’m',
#   'the',
#   'what',
#   'why?',
#   'why?',
#   'one',
#   'some',
#   'how',
#   'shit',
#   'what',
#   'this',
#   'you’re',
#   'you’ve',
#   'what',
#   'shit.',
#   'that',
#   'every',
#   'anybody',
#   'what’s',
#   'she',
#   'what',
#   'you',
#   'what',
#   'he',
#   'what'],
#  'why?': ['‘Cause', '‘Cause', '‘Cause'],
#  'never': ['know',
#   'been',
#   'getting',
#   'seen',
#   'happen',
#   'happen',
#   'call',
#   'see',
#   'see',
#   'gonna',
#   'seen'],
#  'who': ['might', 'the', 'you', 'is', 'does'],
#  'might': ['get', 'be', 'lick'],
#  'get': ['triggered.',
#   'scared.',
#   'you',
#   'cancelled.',
#   'to',
#   'my',
#   'him',
#   'enough',
#   'attention?',
#   'attention.',
#   'attention,',
#   'attention,',
#   'attention',
#   'attention.',
#   'attention,',
#   'you',
#   'up',
#   'attention,',
#   'me',
#   'them',
#   'a',
#   'it',
#   'that',
#   'a',
#   'an',
#   'a',
#   'there,',
#   'in',
#   'drunk.',
#   'busted',
#   'kicked',
#   'a',
#   'a',
#   'her',
#   'you',
#   'that.”',
#   'some',
#   'rich',
#   'these',
#   'these',
#   'these',
#   'these',
#   'these',
#   'these',
#   'estimates',
#   'hard.',
#   'that',
#   'that',
#   'her',
#   'nominated',
#   'nominated',
#   'whooped.'],
#  'triggered.': ['That’s'],
#  'say': ['the',
#   'some',
#   'most',
#   'we’re',
#   'we’re',
#   'we’re',
#   'something.',
#   'the',
#   'dumb',
#   'women',
#   'men',
#   'men',
#   'men'],
#  'wrong': ['thing…', 'with'],
#  'thing…': ['motherfuckers', 'No.', 'It'],
#  'motherfuckers': ['get', 'with', 'are', 'invested', 'on', 'on', 'I'],
#  'scared.': ['You', 'Everybody', 'If', 'In', 'Everybody'],
#  'gotta': ['watch',
#   'watch',
#   'watch',
#   'get',
#   'work',
#   'practice.',
#   'get',
#   'see',
#   'wear',
#   'love',
#   'love',
#   'go',
#   'go.'],
#  'watch': ['out.', 'what', 'out.', 'Emancipation'],
#  'out.': ['You', 'Everybody’s', 'You', 'Let’s', 'They'],
#  'what': ['people',
#   'they',
#   'you',
#   'I’m',
#   'I’m',
#   'Elon',
#   'kind',
#   'kind',
#   'she',
#   'Meghan',
#   'I',
#   'are',
#   'are',
#   'they',
#   'the',
#   'are',
#   'was',
#   'it',
#   'it’s',
#   'kind',
#   'kind',
#   'happened',
#   'the',
#   'everybody',
#   'the',
#   'the',
#   'my'],
#  'say.': ['They', 'You', '‘Cause'],
#  'They': ['always',
#   'just',
#   'say,',
#   'sell',
#   'hate',
#   'hate',
#   'don’t',
#   'sell',
#   'say',
#   'say',
#   'say',
#   'invented',
#   'wanted',
#   'got',
#   'kicked',
#   'want',
#   'always',
#   'got',
#   'say',
#   'say',
#   'say'],
#  'always': ['say,', 'say,', 'got', 'got', 'got'],
#  'say,': ['uh,', '“We', '“Where', '“Chris,', '“Gimme', '“No'],
#  'uh,': ['“words', '“For'],
#  '“words': ['hurt.”'],
#  'hurt.”': ['That’s'],
#  'words': ['hurt.', 'hurt', 'hurt'],
#  'hurt.': ['You', 'People'],
#  'anybody': ['that', 'with'],
#  'says': ['words'],
#  'hurt': ['has', 'when', 'him', 'me.'],
#  'has': ['never',
#   'negative',
#   'lower',
#   'less',
#   'ever',
#   'more',
#   'a',
#   'been',
#   'to',
#   'a',
#   'no',
#   'no',
#   'no',
#   'coffee'],
#  'been': ['punched',
#   'married',
#   'a',
#   'single',
#   'on',
#   'working,',
#   'working',
#   'working',
#   'cheated',
#   'cheated',
#   'interviewed'],
#  'punched': ['in'],
#  'in': ['the',
#   'my',
#   'years.',
#   'years.',
#   'the',
#   'the',
#   'this',
#   'agreement]',
#   'Baltimore',
#   'there,',
#   'America.',
#   'America',
#   'the',
#   'this',
#   'a',
#   'commercials?',
#   'slavery',
#   'here.”',
#   'here,',
#   'his',
#   'tonight.',
#   'some',
#   'and',
#   'bad',
#   'horrible',
#   'a',
#   'the',
#   'most',
#   'this',
#   'there,',
#   'a',
#   'the',
#   'pain]',
#   'the',
#   'a',
#   'kindergarten,',
#   'August,',
#   'Orlando,',
#   'Alabama.',
#   'some',
#   'it.',
#   'trouble',
#   'high',
#   'Portugal,',
#   'the',
#   'school',
#   'no',
#   'the',
#   'the',
#   'all',
#   'Paris.',
#   'Paris.',
#   '1945.',
#   '1945,',
#   'a',
#   'America.',
#   'shape',
#   'just',
#   'any',
#   'America,',
#   'the',
#   'a',
#   'a',
#   'any',
#   'America,',
#   'the',
#   'sweatpants,',
#   'the',
#   'danger.',
#   'my',
#   'Black.',
#   'a',
#   'a',
#   'New',
#   'Pootie',
#   'animation,',
#   'here',
#   'the',
#   'front',
#   'Paris”',
#   'British',
#   'a'],
#  'face.': ['[audience'],
#  'Okay?': ['Yeah,',
#   'Homework,',
#   '[audience',
#   'We',
#   'So,',
#   'And',
#   'And',
#   'And',
#   'Okay?',
#   'And',
#   'That’s'],
#  'Yeah,': ['words',
#   'we',
#   'we',
#   'I',
#   'I’m',
#   'you',
#   'motherfucker.',
#   'n*gga,',
#   'it'],
#  'when': ['you',
#   'I',
#   'I',
#   'I',
#   'I',
#   'the',
#   'did',
#   'you’re',
#   'I',
#   'it’s',
#   'she',
#   'I',
#   'we',
#   'it',
#   'she'],
#  'write': ['them', 'a', 'essays', 'why'],
#  'them': ['on',
#   'woke',
#   'just',
#   'out',
#   'ears.',
#   '“argh”',
#   'not',
#   'as',
#   'to',
#   'to',
#   'to',
#   'like',
#   'good',
#   'all',
#   'crackers',
#   'crackers.”',
#   'for'],
#  'on': ['a',
#   'a,',
#   'a',
#   'ball',
#   'Earth.',
#   'it.',
#   'a',
#   'a',
#   'Pelosi’s',
#   'complaining.',
#   'Oprah,',
#   'me.”',
#   'your',
#   'your',
#   'your',
#   'the',
#   'Earth,',
#   'Earth,',
#   'the',
#   'me.',
#   'a',
#   'the',
#   'a',
#   'the',
#   'trial,',
#   'OnlyFans',
#   'Netflix.',
#   'a',
#   'me,',
#   'this',
#   'one',
#   'the',
#   'your',
#   'the',
#   'a',
#   'pussy.',
#   'pussy.',
#   'pussy',
#   'a',
#   'coming',
#   'a',
#   'Oprah',
#   'camera.',
#   'a',
#   'the',
#   'us',
#   'television.',
#   'this',
#   'her.',
#   'her.',
#   'existence'],
#  'brick,': ['okay?'],
#  'Everybody’s': ['scared.', 'full', 'trying'],
#  'Everybody': ['scared.',
#   'full',
#   'you',
#   'is',
#   'cares',
#   'knows.',
#   'fucking',
#   'that',
#   'in',
#   'called',
#   'called',
#   'called'],
#  'If': ['you', 'you’re', 'my', 'my', 'my', 'you', 'you’re', 'you’re', 'I’m'],
#  'certain': ['age'],
#  'age': ['and'],
#  'go': ['to',
#   'to',
#   'in',
#   'to',
#   'to',
#   'to',
#   'to',
#   'through',
#   'out',
#   'out',
#   'out',
#   'out',
#   'out',
#   'alone',
#   'with'],
#  'work,': ['you', 'motherfucker.', 'and'],
#  'are': ['fucking',
#   'activists.',
#   'sucking',
#   'motherfucking',
#   'not',
#   'addicted',
#   'real',
#   'people',
#   'climbing',
#   'inclusive!',
#   'clearly',
#   'you,',
#   'you?',
#   'good.”',
#   'born',
#   'the',
#   'like,',
#   'born',
#   'rich.',
#   'rich',
#   'like,',
#   'spoiled.',
#   'fucking',
#   'fucking',
#   'fucking',
#   'spoiled,',
#   'kicked',
#   'suing',
#   'you',
#   'mean,',
#   'you’re',
#   'voluntarily',
#   'in',
#   'all,',
#   'fighting',
#   'marked'],
#  'fucking': ['scared.',
#   'sad,',
#   'light-skinned',
#   'spoiled',
#   'did',
#   'spoiled.',
#   'spoiled.',
#   'car',
#   'school.”',
#   'vet,',
#   'date',
#   'is.',
#   'played',
#   'power.',
#   'cent!',
#   'dime.',
#   'dangerous,',
#   'businessman.',
#   'knows.',
#   'last',
#   'Oscars',
#   'her',
#   'low',
#   'bitch.',
#   'said,',
#   'grown-ass',
#   'concussion,'],
#  'In': ['the', 'most'],
#  'old': ['days,', 'neighborhood', 'crackhead.”'],
#  'days,': ['if', 'I'],
#  'somebody': ['wanted', 'wants', 'for', 'else’s'],
#  'wanted': ['your', 'to', 'to'],
#  'your': ['job,',
#   'job,',
#   'yoga',
#   'favorite',
#   'ass.',
#   'ass!',
#   'ass.',
#   'ass.',
#   'love,',
#   'support,',
#   'care.',
#   'momma',
#   'white',
#   'tired,',
#   'poor,',
#   'huddled',
#   'ass',
#   'ass',
#   'ass',
#   'daughters',
#   'hand.”',
#   'daddy!”',
#   'side.',
#   'own',
#   'side!',
#   'side.',
#   'child',
#   'teeth',
#   'teeth',
#   'ass',
#   'phone',
#   '25-year-old',
#   'shoes.”',
#   'shoes,',
#   'shoes?”',
#   'shoes,',
#   'shoes?”',
#   'roof',
#   'dick',
#   'dead',
#   'e-mail\n\n',
#   'inbox!'],
#  'job,': ['they', 'they'],
#  'worked': ['harder', 'with', 'at', 'at', 'at'],
#  'harder': ['than'],
#  'than': ['you.',
#   'Elon',
#   'Elon',
#   'Elon',
#   'Gayle',
#   'Black',
#   'mine.',
#   'Ukraine.',
#   'any',
#   'me.',
#   'licking',
#   'me.',
#   'shoes.',
#   'female',
#   'female',
#   'Joe',
#   'female',
#   'the',
#   'me.',
#   'he'],
#  'Now,': ['somebody',
#   'America’s…',
#   'we',
#   'that',
#   'my',
#   'let',
#   'my',
#   'a',
#   'these',
#   'this',
#   'that’s',
#   'let’s',
#   'I'],
#  'wants': ['your', 'to', 'a'],
#  'wait': ['for', 'before', 'for'],
#  'for': ['you',
#   'social',
#   'marginalized',
#   'manslaughter.',
#   'Subaru.',
#   'Subaru,',
#   '$250',
#   'Elon',
#   'the',
#   'likes.',
#   'attention.',
#   'Thanksgiving,',
#   'the',
#   'more',
#   'an',
#   'your',
#   '18',
#   'a',
#   'ten',
#   'smiling?',
#   'real.',
#   'her',
#   'college,',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'you',
#   'you.',
#   'you',
#   'the',
#   'this',
#   'this',
#   'almost',
#   'one',
#   'that',
#   'that',
#   'some',
#   'me.',
#   'Concussion.”',
#   'Concussion.',
#   'Run-DMC',
#   'Will',
#   'this',
#   'Massa,'],
#  'some': ['dumb',
#   'shit?',
#   'fucked',
#   'vodkas',
#   'in-law',
#   'in-law',
#   'situations',
#   'kid',
#   'people',
#   'nasty',
#   'shit?',
#   'people.”',
#   'shit.”',
#   'bullshit',
#   'sleep',
#   'sort',
#   'life',
#   'reason,',
#   'bitch-ass',
#   'jokes',
#   'great'],
#  'dumb': ['shit.', 'shit'],
#  'shit.': ['Yeah.',
#   'Motherfuckers',
#   '–',
#   'Shoot',
#   'And',
#   'You',
#   'And',
#   'And',
#   'And',
#   '[laughs]',
#   'They',
#   'My',
#   'I',
#   'I',
#   'But',
#   '[audience',
#   'Nobody'],
#  'Yeah.': ['Try', 'Do', 'Culinary', 'Try'],
#  'Try': ['to', 'to', 'to'],
#  'with': ['one',
#   'the',
#   'it',
#   'is',
#   'that',
#   'this?”',
#   'motherfuckers',
#   'paper',
#   'these',
#   'it.',
#   'us.”',
#   'all',
#   'anybody.',
#   'it.',
#   'nothin’?”',
#   'nothin’?”',
#   'afro',
#   'the',
#   'the',
#   'Goofy.',
#   'no',
#   'her,',
#   'my',
#   'that',
#   'that',
#   'her',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'me',
#   'her',
#   'the',
#   'your',
#   'sweatpants',
#   'their',
#   'all',
#   'his',
#   'my',
#   'that',
#   'light-hearted',
#   'sharp',
#   'whimsy'],
#  'one': ['of',
#   'has',
#   'has',
#   'easiest',
#   'of',
#   'reason',
#   'day,',
#   'day,',
#   'of',
#   'hand,',
#   'sec,',
#   'of'],
#  'woke': ['traps.', 'trap', 'ass'],
#  'traps.': ['Say,'],
#  'Say,': ['“Hey,', '“Chris!'],
#  '“Hey,': ['we', 'Fred,', 'n*gga!”', 'we', 'I'],
#  'we': ['going',
#   'sell,',
#   'live',
#   'are.',
#   'can',
#   'just',
#   'live',
#   'live',
#   'check',
#   'going',
#   'would',
#   'would.',
#   'would.',
#   'need',
#   'going',
#   'have',
#   'bought',
#   'went',
#   'went',
#   'were',
#   'finally',
#   'weren’t',
#   'went',
#   'get',
#   'got',
#   'need',
#   'supposed',
#   'all',
#   'hold',
#   'don’t.',
#   'don’t.'],
#  'going': ['to',
#   'with',
#   'on.',
#   'on',
#   'through.',
#   'through.',
#   'in',
#   'to',
#   'to',
#   'on?”',
#   'through',
#   'to',
#   'on,',
#   'good.',
#   'to'],
#  'gay': ['wedding'],
#  'wedding': ['tomorrow.”'],
#  'tomorrow.”': ['“How'],
#  '“How': ['do', 'did', 'come'],
#  'feel': ['about', 'seen,', 'heard.”'],
#  'about': ['that?”',
#   'the',
#   'the',
#   'abortion.”',
#   'abortion.”',
#   'abortion,',
#   'the',
#   'the',
#   'three',
#   'it.',
#   'a',
#   'right',
#   'to',
#   'them',
#   'it.',
#   'it',
#   'my',
#   'Harriet',
#   'my',
#   'it.',
#   'her',
#   'Anita',
#   'a',
#   'it',
#   'this',
#   'her.'],
#  'that?”': ['Oh,'],
#  'Oh,': ['ho,', 'it’s', 'it’s', 'you', 'my'],
#  'ho,': ['ho,', 'ho!'],
#  'ho!': ['“It’s'],
#  '“It’s': ['good.', 'a', 'a', 'a'],
#  'good.': ['It’s', 'Had', 'I', 'I’m', 'The', 'That’s'],
#  'It’s': ['good.”',
#   'why',
#   'like',
#   'the',
#   'the',
#   'so',
#   'very',
#   'been',
#   'better',
#   'never',
#   'like,'],
#  'good.”': ['Don’t', '“All', 'Shut'],
#  'Don’t': ['fall', 'get', 'hate', 'fight'],
#  'fall': ['into'],
#  'trap': ['at'],
#  'at': ['all',
#   'all.',
#   'AT&T,',
#   'him.',
#   'a',
#   'the',
#   'work,',
#   'a',
#   'a',
#   'first.',
#   'my',
#   'this',
#   'that',
#   'all.',
#   'all.',
#   'a',
#   '12:15',
#   '12:15',
#   'all.',
#   'Beyoncé.',
#   'Burger',
#   'Burger',
#   'Burger',
#   'me,',
#   'the',
#   'the',
#   'Knoxville’s',
#   'aging,'],
#  'all': ['now.',
#   'for',
#   'for,',
#   'right?',
#   'dumb,',
#   'sort',
#   'the',
#   'these',
#   'got',
#   'out,',
#   'sad.',
#   'children',
#   'the',
#   'this',
#   'fucked',
#   'got',
#   'boils',
#   'the',
#   'the',
#   'the',
#   'the',
#   'my',
#   'the',
#   'the',
#   'the',
#   'that',
#   'the',
#   'been'],
#  'now.': ['I', 'They'],
#  'have': ['no',
#   'no',
#   'a',
#   'gone',
#   'a',
#   'a',
#   'to',
#   'to',
#   'to',
#   'two',
#   'two',
#   'complete',
#   'the',
#   'the',
#   'the',
#   'to',
#   'to',
#   'the',
#   'ever',
#   'one.',
#   'all,',
#   'all',
#   'all',
#   'all',
#   'the',
#   'made',
#   'ever',
#   'spent',
#   'all',
#   'all',
#   'ever',
#   'any',
#   'any',
#   'no',
#   'ever'],
#  'problem': ['with', 'with', 'with', 'with'],
#  'wokeness.': ['I'],
#  'it': ['at',
#   'out,',
#   'said,',
#   'was',
#   'ain’t',
#   'was',
#   'was',
#   'right',
#   'right',
#   '’cause',
#   'immediately.',
#   'worse',
#   'twisted,',
#   'is',
#   'done?”',
#   'is',
#   'good.',
#   'much',
#   'tightly.”',
#   'unfolds.”',
#   'right',
#   'would',
#   'was',
#   'would',
#   'for',
#   'was',
#   'dawned',
#   'over',
#   'was',
#   'all',
#   'simmered',
#   'female',
#   'pussy.',
#   'whatever',
#   'on',
#   'again',
#   'on',
#   'for',
#   'up.',
#   'hurt?”',
#   'and',
#   'like',
#   'hurt?',
#   'motherfucking',
#   'is.'],
#  'all.': ['I’m', 'America,', 'Men', 'What,', '[man'],
#  'social': ['justice.', 'worker'],
#  'justice.': ['I’m'],
#  'for,': ['for'],
#  'marginalized': ['people'],
#  'getting': ['their',
#   'a',
#   'a',
#   'her',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'open'],
#  'their': ['rights.',
#   'reaction',
#   'lives.',
#   'bodies,',
#   'mother,',
#   'class',
#   'kids',
#   'sight.”',
#   'boys,',
#   'actual'],
#  'rights.': ['The'],
#  'The': ['thing',
#   'fuck',
#   'biggest',
#   'fuck?',
#   'fuck?',
#   'fuck',
#   'fuck',
#   'fuck?',
#   'Kardashians',
#   'judge',
#   'whole',
#   'phone',
#   'whole',
#   'same',
#   'car',
#   'pussy,',
#   'Rock.',
#   'Rock.',
#   'Breakfast',
#   'View',
#   'Talk'],
#  'thing': ['I', 'I', 'I', 'that', 'humbled'],
#  'selective': ['outrage.', 'outrage.', 'outrage.', 'outrage.'],
#  'outrage.': ['[audience', 'Everybody,', 'Practices', '‘Cause'],
#  'applauding]': ['That’s',
#   '[imperceptible]',
#   'This',
#   '…how',
#   '[man]',
#   'Lola',
#   '[hip-hop'],
#  'right,': ['selective',
#   'man.',
#   'infamy.',
#   'to',
#   'Jackie?',
#   'pro-life,',
#   'fuck',
#   'my',
#   'man.',
#   'man.',
#   'it',
#   'that',
#   'man.',
#   'having',
#   'wherever',
#   'that’s',
#   'women',
#   'man,'],
#  'Everybody,': ['you'],
#  'talking': ['about?',
#   'about.',
#   'about,',
#   'about,',
#   'about,',
#   'about,',
#   'about?',
#   'about?”',
#   'about,',
#   'to',
#   'about',
#   'about',
#   'about'],
#  'about?': ['One', 'These'],
#  'One': ['person', 'of', 'day,'],
#  'person': ['does', 'to', 'to', 'that'],
#  'does': ['something,', 'the', 'for', 'movies', 'that', 'he'],
#  'something,': ['they'],
#  'cancelled.': ['Somebody'],
#  'Somebody': ['else'],
#  'else': ['does'],
#  'exact': ['same', 'opposite.'],
#  'same': ['thing…', 'place.', 'woman', 'woman', 'size,'],
#  'No.': ['You', 'Not', 'No,', 'It’s', 'Fuck'],
#  'about.': ['You', 'My'],
#  'know,': ['like', 'we', 'drives', 'whenever', 'only', 'I', 'I', 'I’m', 'I'],
#  'kind': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'play': ['Michael', 'R.', '“Startin’', '“Bump', 'the', 'that'],
#  'Michael': ['Jackson'],
#  'Jackson': ['songs,'],
#  'songs,': ['but'],
#  'but': ['won’t',
#   'opioids',
#   'it’s',
#   'n*ggas!”',
#   'when',
#   'I',
#   'I',
#   'this',
#   'they',
#   'the',
#   'I',
#   'they',
#   'it’s',
#   'I',
#   'they',
#   'the'],
#  'won’t': ['play', 'find'],
#  'R.': ['Kelly.'],
#  'Kelly.': ['[audience'],
#  'laughing': ['and', 'and', 'and', 'and', 'with,'],
#  '[imperceptible]': ['Same'],
#  'Same': ['crime.'],
#  'crime.': ['One'],
#  'better': ['songs.', 'than', 'the'],
#  'songs.': ['[chuckling]'],
#  '[chuckling]': ['That’s',
#   '“This',
#   'You',
#   'Sad',
#   'God',
#   '[man',
#   'more',
#   'That’s'],
#  'Well,': ['I’ll'],
#  '“Startin’': ['Somethin’,”'],
#  'Somethin’,”': ['it’s'],
#  'it’s': ['a',
#   'me.”',
#   'even',
#   'fucking',
#   'hard',
#   'just',
#   'hard.',
#   'four',
#   'over,',
#   'going',
#   'like',
#   'good.'],
#  'party.': ['I', '“Happy'],
#  '“Bump': ['n’'],
#  'n’': ['Grind,”'],
#  'Grind,”': ['now'],
#  'now': ['you', 'you'],
#  'activists.': ['So,'],
#  'So,': ['everybody’s', 'I’m', 'like,', 'their', 'there’s', 'there’s'],
#  'everybody’s': ['scared.', 'happy'],
#  'full': ['of', 'of', 'of', 'of', 'of'],
#  'shit,': ['you', 'not', 'every', 'man!”', 'everybody'],
#  'know?': ['I’m', 'If'],
#  'neighborhood': ['the', 'you', 'you', 'in', 'in'],
#  'other': ['day.',
#   'day.',
#   'night.',
#   'day,',
#   'day,',
#   'animal’s',
#   'kids.',
#   'night,',
#   'time,',
#   'hand,'],
#  'day.': ['I', 'I', 'It'],
#  'bumped': ['into'],
#  'my,': ['my'],
#  'good': ['friend,',
#   'opioid',
#   'and',
#   'choice.',
#   'lawyers.',
#   'lawyers,',
#   'car.',
#   'name,',
#   'pussy.',
#   '45,'],
#  'friend,': ['Fred.', 'okay?'],
#  'Fred.': ['Hadn’t'],
#  'Hadn’t': ['seen', 'seen'],
#  'seen': ['him', 'him', 'Black', 'me'],
#  'him': ['in',
#   'in',
#   'in',
#   'going,',
#   'way',
#   'a',
#   'my',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'opened',
#   'get',
#   'again,',
#   'again!'],
#  'years.': ['Hadn’t', 'Fred', 'Eighteen', 'Every', 'Seven'],
#  'Fred': ['got'],
#  'new': ['job'],
#  'job': ['at', '’cause'],
#  'AT&T,': ['okay?'],
#  'like,': ['“Hey,',
#   '“Oh,',
#   '“Who',
#   '“Who',
#   '“Subaru,',
#   'no',
#   '“We',
#   '“Didn’t',
#   '“What',
#   '“That’s',
#   '“Why',
#   '“Hey!',
#   'Kris',
#   '“Bipolar',
#   '“Man,',
#   '“Hey.”',
#   '“I',
#   '“Chris,',
#   '“I',
#   '“I’m',
#   '“You',
#   '“Lola,',
#   '“Let’s',
#   '“No,',
#   '“Okay,',
#   'three',
#   '“Lola,',
#   '“Daddy,',
#   '“Look',
#   '“Hey,',
#   '“Lola,',
#   '“I',
#   '“This',
#   '“Did',
#   '“Ah,',
#   '“You',
#   '“Can',
#   '“You',
#   '“Who',
#   '“No,',
#   '“That’s',
#   'The',
#   '“Did',
#   '“Hey,'],
#  'Fred,': ['how’s'],
#  'how’s': ['the'],
#  'job?”': ['And'],
#  'And': ['Fred’s',
#   'I’m',
#   'I’m',
#   'then,',
#   'I’m',
#   'then',
#   'they’re',
#   'how',
#   'the',
#   'right',
#   'sometimes',
#   'they',
#   'from',
#   'soon',
#   'God',
#   'I’m',
#   'I’ve',
#   'then,',
#   'I’m',
#   'because',
#   'people',
#   'they',
#   'they',
#   'my',
#   'Zahra',
#   'I',
#   'when',
#   'we’re',
#   'we’re',
#   'my',
#   'they',
#   'then',
#   'one',
#   'then',
#   'rich-ass',
#   'they',
#   'they',
#   'I',
#   'I',
#   'I’m',
#   'Lola’s',
#   'I’m',
#   'at',
#   'I',
#   'they',
#   'I',
#   'Lola',
#   'then',
#   'I',
#   'to',
#   'her',
#   'the',
#   'they',
#   'when',
#   'now,',
#   'my',
#   'if',
#   'think',
#   'Lola,',
#   'suddenly',
#   'the',
#   'if',
#   'if',
#   'everybody’s',
#   'they',
#   'then',
#   'you',
#   'the',
#   'then',
#   'then',
#   'I',
#   'every',
#   'if',
#   'people',
#   'by',
#   'The',
#   'who',
#   'then',
#   'now,'],
#  'Fred’s': ['like,'],
#  '“Oh,': ['I'],
#  'love': ['the',
#   'Snoop.',
#   'Snoop',
#   'Black',
#   'Black',
#   'the',
#   'the',
#   'about',
#   'how',
#   'to',
#   'everybody,',
#   'all.',
#   'my',
#   'them',
#   'them',
#   'my',
#   'my',
#   'Men',
#   'Will',
#   'this',
#   'this'],
#  'job.”': ['“It’s'],
#  'safe': ['space.”', 'space?', 'around'],
#  'space.”': ['“I'],
#  '“I': ['feel',
#   'think',
#   'didn’t',
#   'didn’t',
#   'don’t',
#   'hope',
#   'want',
#   'can’t',
#   'know',
#   'know',
#   'need',
#   'need',
#   'need',
#   'told',
#   'told',
#   'want',
#   'saw',
#   'saw',
#   'really',
#   'want',
#   'need',
#   'only'],
#  'seen,': ['I'],
#  'heard.”': ['“There’s'],
#  '“There’s': ['a'],
#  'lot': ['of', 'of', 'of', 'of', 'of', 'of'],
#  'diversity.”': ['And'],
#  'looking': ['at'],
#  'him.': ['I’m'],
#  'like…': ['“N*gga,', '[screeches]'],
#  '“N*gga,': ['it’s'],
#  'me.”': ['What,', '[chuckling]', '[normal', '“My', '“That’s'],
#  'What,': ['you', '’cause', 'I'],
#  'wearing': ['a'],
#  'wire': ['or'],
#  'or': ['some',
#   'hate.”',
#   'hate.”',
#   'three',
#   'Robert',
#   'some',
#   'pussy',
#   'Gayle'],
#  'shit?': ['What', 'No', 'Portugal.', 'They', 'She'],
#  'What': ['the',
#   'the',
#   'would',
#   'the',
#   'the',
#   'that',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the'],
#  'fuck': ['you',
#   'you',
#   'out',
#   'is',
#   'is',
#   'is',
#   'is',
#   'nothing',
#   'that',
#   'you',
#   'trimester.',
#   'up.',
#   'up,',
#   'she',
#   'with',
#   'is',
#   'that.”',
#   'all',
#   'Doja',
#   'happened.',
#   'would',
#   'happened,',
#   'out',
#   'happened.'],
#  'about,': ['safe', 'man?', '“she', '“I', '“Touché,'],
#  'space?': ['N*gga,'],
#  'did': ['eight', 'white', 'Snoop', 'it.', 'it.', 'it,', 'not', 'that'],
#  'eight': ['years'],
#  'years': ['for',
#   'ago,',
#   'old.',
#   'ago,',
#   'later,',
#   'younger',
#   'old.',
#   'old!',
#   'old.'],
#  'manslaughter.': ['Nobody’s'],
#  'Nobody’s': ['safe'],
#  'around': ['you.', 'your'],
#  'Motherfuckers': ['typing'],
#  'typing': ['out'],
#  'out': ['woke',
#   'the',
#   'of',
#   'of',
#   'key',
#   'the',
#   'there',
#   'drinking,',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'first,',
#   'of',
#   'till',
#   'of',
#   'by',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'and',
#   'the',
#   'of'],
#  'ass': ['tweets', 'in', 'here.”', 'here.”', 'on', 'out', 'and', 'tonight.'],
#  'tweets': ['on'],
#  'a,': ['on', 'he'],
#  'phone': ['made', 'rang.', 'and', 'three'],
#  'made': ['by', 'millions', 'I', 'brand-new', 'some'],
#  'by': ['child',
#   'that',
#   'and',
#   'her',
#   'her',
#   'her',
#   'her',
#   'her',
#   'your',
#   'a',
#   'who’s',
#   'who’s',
#   'Suge',
#   'this',
#   'the',
#   'the'],
#  'child': ['slaves.',
#   'you’re',
#   'is',
#   'is',
#   'to',
#   'for',
#   'to',
#   'out',
#   'out',
#   'and',
#   'and'],
#  'slaves.': ['You'],
#  'cut': ['it'],
#  'out,': ['man.', 'I', 'but', 'and', 'and', 'like', 'and'],
#  'man.': ['Not',
#   'They',
#   'The',
#   'Just',
#   'We',
#   'America’s',
#   'Republicans',
#   '“Is',
#   'My',
#   'And',
#   'When',
#   'My',
#   'I',
#   'Cannot',
#   'Yeah.',
#   'Shit,',
#   'Women',
#   'She’s',
#   'Did',
#   'What'],
#  'Not': ['only', 'even', 'me.'],
#  'only': ['is', 'is', 'people', 'animal', 'got'],
#  'everybody': ['full',
#   'full',
#   'claims',
#   'in.',
#   'in.',
#   'else.',
#   'knows',
#   'knows.',
#   'in'],
#  'not': ['only',
#   'go?”',
#   'the',
#   'dissing',
#   'racism!',
#   'racist!”',
#   'just',
#   'just',
#   'get',
#   'let',
#   'advocating',
#   'talking',
#   'at',
#   'date',
#   'working?',
#   'working.',
#   'working.',
#   'a',
#   'need',
#   'need',
#   'a',
#   'fighting.',
#   'the',
#   'have',
#   'talk',
#   'be'],
#  'every': ['business',
#   'Lululemon,',
#   'Subaru',
#   'week.',
#   'time',
#   'woman',
#   'hand',
#   'dime',
#   'rapper'],
#  'business': ['is'],
#  '–': ['[man', 'Explore'],
#  'whooping]': ['Everybody'],
#  'business,': ['they'],
#  'even': ['tell',
#   'like',
#   'formed.',
#   'close,',
#   'if',
#   'Black',
#   'know',
#   'believe',
#   'realize',
#   'realize',
#   'realize.',
#   'know',
#   'with',
#   'in'],
#  'tell': ['you', 'you', 'none', 'you', 'what', 'what', 'on'],
#  'product': ['no'],
#  'more.': ['They'],
#  'how': ['much',
#   'you',
#   'do',
#   'racist',
#   'brown',
#   'brown',
#   'quickly',
#   'it',
#   'this',
#   'it',
#   'you',
#   'fine',
#   'it',
#   'come'],
#  'charity': ['they'],
#  'do.': ['They', 'And'],
#  '“We': ['give', 'like', 'don’t', 'just', 'don’t', 'don’t', 'gotta', 'are'],
#  'give': ['back.”', 'back.”', 'back.”', 'me', 'a', 'me', 'a', 'me', 'him'],
#  'back.”': ['“We', '“We', 'I’m', '“How'],
#  'money.”': ['“We'],
#  'mall': ['the'],
#  'went': ['by', 'through', 'to', 'on', 'to', 'to', 'on', 'to', 'home,', 'to'],
#  'store.': ['What’s'],
#  'this': ['thing?',
#   'crowd',
#   'world.',
#   'girl',
#   'a',
#   'day',
#   'shit',
#   'room.”',
#   'is',
#   'counts',
#   'school,',
# ...
#   'get',
#   'made.',
#   'made',
#   'notice',
#   'seen.',
#   'been'],
#  'paid': ['to', 'for', 'more'],
#  'come': ['to', 'home', 'with', '’cause', 'you', 'you'],
#  'there,': ['yeah.”', 'they', '’cause', 'we', '’cause', 'okay?'],
#  'yeah.”': ['That’s'],
#  'opioids,': ['but'],
#  'biggest': ['addiction', 'addiction'],
#  'addiction': ['in', 'in'],
#  'America.': ['No.', 'I’m'],
#  'close,': ['man.'],
#  'America': ['is', 'is'],
#  'attention.': ['That’s',
#   'Can’t',
#   'Feening',
#   'Addicted',
#   'And',
#   'Number',
#   'Number'],
#  'Can’t': ['get', 'wait'],
#  'enough': ['attention.'],
#  'Feening': ['for'],
#  'likes.': ['Just', 'Posting'],
#  'Just': ['feening.', 'feening', 'complaining.', 'give', 'by', 'look'],
#  'feening.': ['We'],
#  'used': ['to', 'to', 'to', 'to'],
#  'love.': ['Now,'],
#  'Posting': ['up'],
#  'up': ['pathetic',
#   'shit.',
#   'a',
#   'in',
#   'with',
#   'walls',
#   'a',
#   'a',
#   'to',
#   'to',
#   'right',
#   'the',
#   'on',
#   'car',
#   'my',
#   'her',
#   'at',
#   'for',
#   'for'],
#  'pathetic': ['pictures.'],
#  'pictures.': ['[high-pitch'],
#  '[high-pitch': ['voice]'],
#  'voice]': ['“This', 'Oh,', 'It’s', 'I’m', 'And', 'And', 'No.'],
#  '“This': ['is', 'is', 'pillowcase'],
#  'eating': ['sushi.'],
#  'sushi.': ['Like'],
#  'Like': ['me.”', 'me.”', 'Serena', 'white', 'the', 'I’m', 'a'],
#  'me,': ['25', 'I', 'okay?', 'a'],
#  '25': ['years', 'year'],
#  'ago,': ['when', 'my', 'fucking', 'his'],
#  'hot.': ['Like'],
#  '[normal': ['voice]', 'voice]', 'voice]', 'voice]', 'voice]', 'voice]'],
#  'sad,': ['man.'],
#  'feening': ['for'],
#  'Addicted': ['to'],
#  'attention?': ['Four'],
#  'Four': ['easy'],
#  'easy': ['ways'],
#  'ways': ['to'],
#  'Number': ['one', 'two', 'three'],
#  'easiest': ['way', 'way', 'way', 'way'],
#  'way': ['to', 'to', 'to', 'to', 'before', 'more'],
#  'attention,': ['show', 'even', 'that’s', 'but', 'number'],
#  'ass.': ['Show', 'That’s', 'Number', 'That’s', 'There’s'],
#  'Show': ['your'],
#  'ass!': ['You', 'That’s'],
#  'will': ['get',
#   'get',
#   'get',
#   'fuck',
#   'lick',
#   'model',
#   'model',
#   'drive',
#   'never',
#   'never',
#   'not'],
#  'world': ['we', 'where', 'where', 'called', 'Kevin'],
#  'in.': ['It’s', 'That’s', 'She’s', 'But'],
#  'Blac': ['Chyna'],
#  'Chyna': ['has', 'is'],
#  'followers': ['than'],
#  'Gayle': ['King.', 'crying.'],
#  'King.': ['‘Cause'],
#  'showing': ['that'],
#  'So': ['number',
#   'about',
#   'their',
#   'Lola',
#   'all',
#   'we',
#   'Lola’s',
#   'I',
#   'she',
#   'now',
#   'then'],
#  'number': ['one,', 'four', 'four,'],
#  'one,': ['show'],
#  'two': ['easiest',
#   'white',
#   'beautiful',
#   'beautiful',
#   'or',
#   'days',
#   'talented'],
#  'attention': ['is'],
#  'infamous.': ['Yeah.'],
#  'Do': ['some', 'you', 'you', 'you'],
#  'fucked': ['up', 'up.', 'up,', 'up'],
#  'Shoot': ['up'],
#  'school.': ['Try', 'So', 'I', 'Touché,', 'Touché,'],
#  'stab': ['Dave'],
#  'Dave': ['Chappelle'],
#  'Chappelle': ['at'],
#  'infamy.': ['You'],
#  'three': ['easiest',
#   'grandchildren!',
#   'days.',
#   'years',
#   'of',
#   'years',
#   'weeks'],
#  'excellent.': ['That’s', 'You'],
#  'Serena': ['Williams,'],
#  'Williams,': ['greatest'],
#  'greatest': ['tennis', 'achievement,'],
#  'tennis': ['player'],
#  'player': ['to'],
#  'game.': ['[audience', 'You’re'],
#  'Absolutely': ['excellent!'],
#  'excellent!': ['Being'],
#  'Being': ['excellent'],
#  'excellent': ['will'],
#  'hard': ['being', 'life.', 'as'],
#  'being': ['excellent.', 'so'],
#  'morning.': ['[laughs]'],
#  'practice.': ['It'],
#  'It': ['is',
#   'ain’t',
#   'was',
#   'wouldn’t',
#   'was',
#   'had',
#   'was',
#   'worked.',
#   'really',
#   'really',
#   'happened.',
#   'still',
#   'got'],
#  'easier': ['to'],
#  'four': ['easiest', 'years', 'seasons.”', 'of'],
#  'four,': ['is'],
#  'victim.': ['[audience]', 'People', 'Like,'],
#  '[audience]': ['Ooh.'],
#  'Ooh.': ['It’s'],
#  'this?”': ['[audience'],
#  'laughs]': ['Don’t', 'That’s', 'Goddamn.', 'God', 'No,'],
#  'wrong,': ['there’s'],
#  'victim-shaming': ['going'],
#  'on.': ['No.', 'Everybody', 'None'],
#  'real': ['victims', 'victims', 'relationship.'],
#  'victims': ['in', 'need'],
#  'world.': ['There', 'Republicans'],
#  'gone': ['through'],
#  'through': ['unspeakable', 'was', 'it', 'the'],
#  'unspeakable': ['trauma,'],
#  'trauma,': ['and'],
#  'love,': ['your'],
#  'support,': ['and'],
#  'care.': ['But'],
#  'But': ['if',
#   'it',
#   'since',
#   'let’s',
#   'I',
#   'I',
#   'of',
#   'if',
#   'if',
#   'I',
#   'you',
#   'we',
#   'even',
#   'I’m',
#   'for'],
#  'claims': ['to'],
#  'victim': ['when'],
#  'help,': ['ain’t'],
#  'nobody': ['gonna'],
#  'gonna': ['be',
#   'be.”',
#   'be.”',
#   'be!',
#   'get.',
#   'have',
#   'say',
#   'accept',
#   'learn',
#   'put',
#   'leave',
#   'sneak',
#   'sue',
#   'sue',
#   'sue',
#   'take',
#   'happen.',
#   'happen.'],
#  'there': ['to', 'a', 'waiting', 'like'],
#  'them,': ['okay?', '“Dogg-ages.”'],
#  'now,': ['we', 'man.', 'if', 'half', 'before', 'three', 'twice', 'I'],
#  'where': ['the', 'they', 'I', 'women', 'I'],
#  'emergency': ['room'],
#  'room': ['is'],
#  'filled': ['up'],
#  'paper': ['cuts.'],
#  'cuts.': ['Okay?'],
#  'cheering': ['and', 'and', 'and'],
#  'whistling]': ['That’s', '…that'],
#  'trying': ['to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to'],
#  'People': ['that', 'are'],
#  'goddamn': ['well'],
#  'well': ['they'],
#  'victims.': ['Like'],
#  'white': ['men.',
#   'men',
#   'Planet',
#   'men',
#   'couples',
#   'in-laws.',
#   'in-laws.',
#   'girl',
#   'girl',
#   'in-laws.',
#   'in-laws.',
#   'in-laws,',
#   'people',
#   'girl',
#   'schools,',
#   'schools',
#   'parents.',
#   'parents',
#   'girl',
#   'dentist.',
#   'dentist,',
#   'people.'],
#  'men.': ['When'],
#  'When': ['did', 'I', 'they', 'I'],
#  'men': ['become',
#   'actually',
#   'actually',
#   'trying',
#   'think',
#   'date',
#   'have',
#   'have',
#   'have',
#   'in',
#   'don’t'],
#  'become': ['victims?', 'Morgan'],
#  'victims?': ['White'],
#  'White': ['men', 'men', 'men'],
#  'actually': ['think', 'think', 'prefer'],
#  'losing': ['the', 'the', 'the'],
#  'country.': ['To', 'In'],
#  'who?': ['It'],
#  'us.': ['When’s', 'It’s'],
#  'When’s': ['the'],
#  'last': ['time', 'time', 'week,'],
#  'Black': ['cruise',
#   'airline?',
#   'couples',
#   'people',
#   'child',
#   'girl',
#   'girl',
#   'in-laws.',
#   'girl',
#   'girl',
#   'grandma.',
#   'people',
#   'people',
#   'people.',
#   'history?',
#   'excellence.',
#   'people',
#   'girls,',
#   'girls',
#   'ass',
#   'child',
#   'person',
#   'person',
#   'child',
#   'dentist,'],
#  'cruise': ['ship?'],
#  'ship?': ['Or'],
#  'Or': ['flew', 'a'],
#  'flew': ['on'],
#  'airline?': ['Get'],
#  'Get': ['the', 'your', 'the', 'the'],
#  'here.': ['We', 'I'],
#  'money!': ['We'],
#  'vodkas': ['and'],
#  'couple': ['of'],
#  'record': ['companies.'],
#  'companies.': ['White'],
#  'country!': ['Can'],
#  'Can': ['you', 'I', 'I', 'I', 'I'],
#  'believe–': ['Did'],
#  'Did': ['you', 'you', 'it'],
#  'see': ['the',
#   'the',
#   'what',
#   'the',
#   'how',
#   'how',
#   'Lola',
#   'this',
#   'contractors',
#   'you',
#   'women',
#   'men',
#   'me',
#   'it.',
#   'him'],
#  'Capitol': ['riots?', 'riots?'],
#  'riots?': ['White', 'Like,'],
#  'overthrow': ['the'],
#  'government': ['that'],
#  'run!': ['[audience'],
#  'fuck?': ['They’re',
#   'What',
#   'It’s',
#   'She',
#   'God,',
#   'We',
#   'I',
#   'What',
#   'So',
#   'That’s'],
#  'They’re': ['like,', 'the', 'the', 'the', 'so', 'a', 'the', 'gonna', 'like,'],
#  'office.”': ['Who?'],
#  'Who?': ['“Us.”'],
#  '“Us.”': ['[laughs]'],
#  'Planet': ['of'],
#  'Apes': ['shit'],
#  'shit': ['was',
#   'on',
#   'she',
#   'is',
#   'happen–',
#   'is',
#   'like',
#   'about',
#   'they',
#   'on',
#   'was',
#   'on'],
#  'that?': ['These', 'Why'],
#  'These': ['motherfuckers', 'motherfuckers', 'n*ggas'],
#  'climbing': ['up'],
#  'walls': ['and'],
#  'taking': ['a'],
#  'Pelosi’s': ['desk.'],
#  'desk.': ['What'],
#  'make': ['white', 'this', 'no', 'you'],
#  'country?': ['What?'],
#  'What?': ['What?', 'What?', 'What,'],
#  '’cause': ['there’s',
#   'I’m',
#   'the',
#   'Disney’s',
#   'Lola',
#   'they’re',
#   'they’re',
#   'they’re',
#   'if',
#   'Will',
#   'her'],
#  'couples': ['in', 'either.'],
#  'commercials?': ['There’s'],
#  'either.': ['Every'],
#  'mixed': ['race'],
#  'race': ['couple.'],
#  'couple.': ['Everything!'],
#  'Everything!': ['Shit,'],
#  'saw': ['a', 'a', 'a', 'these', 'these', 'him'],
#  'day,': ['saw', 'Snoop', 'the', 'Lola,', 'I', 'Lola'],
#  'Japanese': ['woman'],
#  'woman': ['married', 'in', 'that', 'now,', 'does', 'I', 'can', 'I'],
#  'married': ['to', 'nine', 'for'],
#  'caterpillar.': ['[chuckles]'],
#  'Their': ['kids'],
#  'kids': ['were',
#   'here,',
#   'say',
#   'for',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'to',
#   'to',
#   'went',
#   'speak',
#   'ski,',
#   'are',
#   'had',
#   'get'],
#  'were': ['squirrels!', 'little', 'backstage', 'going', 'lawyers,', 'a'],
#  'squirrels!': ['By'],
#  'By': ['the', 'the'],
#  'way,': ['speaking', 'that', 'he'],
#  'speaking': ['of'],
#  'commercials,': ['when'],
#  'Snoop': ['Dogg', 'was', 'Okay,'],
#  'Dogg': ['become'],
#  'Morgan': ['Freeman?'],
#  'Freeman?': ['[audience'],
#  'This': ['n*gga’s', 'has', 'guy'],
#  'n*gga’s': ['selling'],
#  'everything.': ['Beer,'],
#  'Beer,': ['wine,'],
#  'wine,': ['tampons…'],
#  'tampons…': ['I'],
#  'reverse': ['mortgages.'],
#  'mortgages.': ['Called'],
#  'Called': ['them,'],
#  '“Dogg-ages.”': ['What'],
#  'fuck’s': ['a', 'a'],
#  '“Dogg-age”?': ['I'],
#  'Snoop.': ['I'],
#  'Okay,': ['so'],
#  'just…': ['I’m'],
#  'dissing': ['Snoop,'],
#  'Snoop,': ['all'],
#  'right?': ['Last',
#   '[audience',
#   '[man',
#   'And…',
#   'But',
#   'And',
#   'And',
#   'I',
#   'And',
#   'And'],
#  'Last': ['thing'],
#  'another': ['mad', 'kind', 'quarter', 'high', 'rapper'],
#  'mad': ['rapper,', 'at', 'at'],
#  'rapper,': ['right?'],
#  'Nope.': ['Nope,'],
#  'Nope,': ['nope.'],
#  'nope.': ['No,'],
#  'Back': ['to'],
#  'what’s': ['this', 'so', 'wrong'],
#  'girl': ['Meghan',
#   'trying',
#   'trying',
#   'trying',
#   'home',
#   'trying',
#   'trying',
#   'friends',
#   'friends,'],
#  'Meghan': ['Markle?', 'Markle’s', 'Markle,'],
#  'Markle?': ['[groans]'],
#  '[groans]': ['Seemed'],
#  'Seemed': ['like'],
#  'nice': ['lady.', 'neighborhood.'],
#  'lady.': ['Just'],
#  'complaining.': ['I', 'Acting'],
#  '“Didn’t': ['she'],
#  'she': ['hit',
#   'don’t',
#   'talking',
#   'talking',
#   'talking',
#   'went',
#   'talking',
#   'going',
#   'is.',
#   'was',
#   'ends',
#   'had',
#   'had',
#   'got',
#   'had',
#   'got',
#   'was',
#   'just',
#   'will',
#   'goes,',
#   'talented.',
#   'worked',
#   'could',
#   'is.',
#   'worked',
#   'could'],
#  'hit': ['the', 'man.', 'like'],
#  'light-skinned': ['lottery?”', 'lottery,'],
#  'lottery?”': ['Hit'],
#  'Hit': ['the', 'him', 'him'],
#  'lottery,': ['and'],
#  'still': ['going', 'bad!', 'fuck', 'marry', 'get', 'marry', 'hurts.'],
#  'Acting': ['all'],
#  'dumb,': ['like'],
#  'nothing.': ['Going'],
#  'Going': ['on'],
#  'Oprah,': ['[voice'],
#  '[voice': ['breaking]', 'breaking]'],
#  'breaking]': ['“I', '“Oprah,'],
#  'didn’t': ['know.',
#   'google',
#   'know”?',
#   'know”?',
#   'want',
#   'want',
#   'know',
#   'know',
#   'get',
#   'have',
#   'get',
#   'get',
#   'do',
#   'do'],
#  'know.': ['I', 'She'],
#  'had': ['no',
#   'it',
#   'a',
#   'to',
#   'anything',
#   'anything',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'a',
#   'nothing',
#   'been'],
#  'idea': ['how', 'I', 'I', 'why'],
#  'were.”': ['[normal'],
#  'royal': ['family.', 'family!'],
#  'family.': ['You', 'I–'],
#  'google': ['these'],
#  'motherfuckers?': ['[chuckles]'],
#  '“she': ['didn’t'],
#  'know”?': ['The', 'That’s'],
#  'family!': ['They’re'],
#  'original': ['racists!', 'recipe.'],
#  'racists!': ['They'],
#  'invented': ['colonialism!'],
#  'colonialism!': ['They’re'],
#  'OGs': ['of'],
#  'racism.': ['They’re', 'Like,', 'The'],
#  'Sugarhill': ['Gang'],
#  'Gang': ['of'],
#  '“The': ['hip-hop,', 'craziest', 'fuck,', 'fuck'],
#  'hip-hop,': ['the'],
#  'hippie,': ['the'],
#  'hippie-dippie': ['hip'],
#  'hip': ['hip-hop'],
#  'hip-hop': ['and'],
#  'stop”': ['of'],
#  'marrying': ['into'],
#  'Budweiser': ['family'],
#  'family': ['and'],
#  'going,': ['“They', '“Hey!'],
#  '“They': ['drink', 'wanted'],
#  'drink': ['a'],
#  'lot!”': ['The'],
#  'invested': ['in'],
#  'slavery': ['like'],
#  'Shark': ['Tank.'],
#  'Tank.': ['[laughs]'],
#  '“They’re': ['so', 'so'],
#  'racist.': ['They’re', 'They'],
#  'racist.”': ['Some', '“No'],
#  'Some': ['of'],
#  'racism!': ['It'],
#  'in-law': ['shit.', 'shit!'],
#  'sometimes': ['it’s'],
#  'shit!': ['‘Cause'],
#  'she’s': ['complaining,', 'with', 'in', 'sitting', 'like,', 'like,'],
#  'complaining,': ['and'],
#  '“What': ['the', 'the', 'is'],
#  'about?”': ['[voice'],
#  '“Oprah,': ['they’re'],
#  'racist!”': ['“They', '‘Cause'],
#  'brown': ['the', 'the', 'the'],
#  'baby': ['was', 'gonna', 'gonna', 'until', 'till'],
#  'be.”': ['“They’re', '[normal'],
#  'baby’s': ['gonna'],
#  '“That’s': ['not', 'a', 'my', 'the', '$500,”'],
#  'wanna': ['know…', 'be'],
#  'know…': ['[audience'],
#  '…how': ['brown'],
#  'be!': ['Shit,'],
#  'check': ['behind', 'my'],
#  'behind': ['them'],
#  'ears.': ['That’s'],
#  'scientific': ['test.'],
#  'test.': ['[chuckles]'],
#  'get.': ['Is'],
#  'Is': ['this'],
#  'Steph': ['Curry'],
#  'Curry': ['baby?'],
#  'baby?': ['Or', 'That'],
#  'Draymond': ['Green', 'baby', 'Black,', 'Green'],
#  'Green': ['baby?', 'sleep'],
#  'That': ['Draymond',
#   'n*gga',
#   'would',
#   'shit',
#   'don’t',
#   'is',
#   'ain’t',
#   'is',
#   'is'],
#  'life.': ['Draymond', 'Now,', 'I'],
#  'Black,': ['baby.', 'and', 'football', 'football-playing'],
#  'n*gga': ['dark.', 'he', 'gives'],
#  'dark.': ['He’s'],
#  '“sneak-up-on-you”': ['Black.'],
#  'Black.': ['Where', '[normal'],
#  'Where': ['you'],
#  'at,': ['Draymond?'],
#  'Draymond?': ['“Right'],
#  '“Right': ['here.”'],
#  'here.”': ['Hey!', '“Come', '“Let', '“Help'],
#  'Hey!': ['Hey!', 'Put'],
#  'Put': ['a', 'a'],
#  'bell': ['on,'],
#  'on,': ['n*gga!', 'from', 'Robert', 'but'],
#  'n*gga!': ['Put'],
#  'bell!': ['I'],
#  'through.': ['I', 'I-I'],
#  'Markle’s': ['going'],
#  'I-I': ['know'],
#  'her': ['dilemma.',
#   'white',
#   'white',
#   'Black',
#   'white',
#   'white',
#   'mother',
#   'to',
#   'mother',
#   'teeth?',
#   'mannequins',
#   'nature.',
#   'little',
#   'out',
#   'back',
#   'little',
#   'Black',
#   'lesson',
#   'out.',
#   'the',
#   'mother',
#   'to',
#   'teeth',
#   'granddaughter,',
#   'down',
#   'about',
#   'life,',
#   'to',
#   'car.',
#   'a',
#   'son’s',
#   'husband'],
#  'dilemma.': ['Black', 'Black'],
#  'accepted': ['by', 'by', 'by', 'by', 'by', 'by', 'Caitlyn.'],
#  'in-laws.': ['Oh,', 'It’s', 'Now,', 'Black', 'I’m'],
#  'hard.': ['Black', 'It’s', 'Shit,', '‘Cause', 'You'],
#  'very': ['hard!', 'tight-knit', 'testy'],
#  'hard!': ['But'],
#  'really': ['hard.', 'there,', 'like', 'is,', 'is.', 'fucking', 'knows'],
#  'bring': ['a'],
#  'home': ['for', 'for', 'from'],
#  'Thanksgiving,': ['your'],
#  'momma': ['gonna'],
#  'something.': ['Your', 'Do'],
#  'Your': ['momma’s', 'email'],
#  'momma’s': ['like,'],
#  'worker': ['at'],
#  'table?”': ['Like,'],
#  '“Momma,': ['that’s'],
#  'Jackie!”': ['“We’ve'],
#  '“We’ve': ['been'],
#  'nine': ['years!”'],
#  'years!”': ['“You'],
#  '“You': ['got',
#   'know',
#   'have',
#   'are',
#   'can',
#   'like',
#   'like',
#   'like',
#   'like',
#   'know',
#   'guys'],
#  'grandchildren!': ['Stop'],
#  'Stop': ['being', 'letting'],
#  'mean!”': ['“You'],
#  'playing,': ['right,'],
#  'Jackie?': ['Just'],
#  'time.”': ['Nah,', 'And', 'We’re'],
#  'Nah,': ['nah,'],
#  'nah,': ['nah.'],
#  'nah.': ['Meghan'],
#  'Markle,': ['I'],
#  '“Hey!': ['If', 'Hey!”'],
#  'in-laws,': ['then'],
#  'marry': ['a', 'Jay-Z.', 'Jay-Z.'],
#  'Kardashian.”': ['‘Cause'],
#  'accept': ['everybody.',
#   'the',
#   'it',
#   'it',
#   'everyone,',
#   'it.',
#   'it',
#   'it',
#   'the'],
#  'everybody.': ['So,'],
#  'Kris': ['Jenner', 'Jenner', 'Jenner.'],
#  'Jenner': ['is', 'lets'],
#  'Statue': ['of'],
#  'Liberty.': ['“Give'],
#  '“Give': ['me'],
#  'tired,': ['your'],
#  'poor,': ['your'],
#  'huddled': ['masses…”'],
#  'masses…”': ['Kris'],
#  'lets': ['everybody', 'everybody'],
#  'She’s': ['like', 'like,', 'like,', 'extremely'],
#  'grandma.': ['She'],
#  'fix': ['you', 'you', 'my'],
#  'plate,': ['that', 'you'],
#  'Jenner.': ['She'],
#  'fuck.': ['She', 'But'],
#  '“Bipolar': ['rapper?'],
#  'rapper?': ['Bring'],
#  'Bring': ['your', 'your', 'your'],
#  '“Come': ['in'],
#  'here,': ['you', 'n*gga,', 'man.'],
#  'genius,': ['bipolar'],
#  'bipolar': ['motherfucker.”'],
#  'motherfucker.”': ['“Crackhead', 'And'],
#  '“Crackhead': ['basketball'],
#  'basketball': ['player?'],
#  'player?': ['Bring'],
#  '“Let': ['me'],
#  'crackhead.”': ['“Daddy'],
#  '“Daddy': ['got'],
#  'titties?': ['Bring'],
#  '“Help': ['me'],
#  'plates.”': ['[laughs]'],
#  'Kardashians': ['are'],
#  'inclusive!': ['And'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(chris_dict)
# Out:
# 'Send you know? I’m like, The fuck out with Goofy. Fucking drums, please. But if.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %% [markdown]
# #### Generate sentence for other comedians also

# %%
import pandas as pd

# Assuming you have the data stored in a pandas DataFrame called `data`

# Extracting the transcript for Chris Rock, Dave Chappelle, and Kevin Hart
dave_chappelle = data.transcript.loc['dave_chappelle']
kevin_hart = data.transcript.loc['kevin_hart']

# Let's print the first 200 characters of each comedian's transcript

print("\nDave Chappelle's transcript (first 200 characters):")
print(dave_chappelle[:200])

print("\nKevin Hart's transcript (first 200 characters):")
print(kevin_hart[:200])
# Out:
# Dave Chappelle's transcript (first 200 characters):
# “The Dreamer,” which was shot in Chappelle’s hometown of Washington, D.C., at the Lincoln Theatre, marks Chappelle’s seventh special with Netflix. Stan Lathan, who directed Chappelle’s six other speci
#
# Kevin Hart's transcript (first 200 characters):
# Streaming on Netflix from November 17, 2020   [Kenzo babbling] [Kevin] Yo. What’s up? I was looking all over the house for y’all. [Eniko] We’re just chilling. About to go downstairs, get some work don

# %%
# Create Markov chain dictionaries for Dave Chappelle and Kevin Hart
dave_dict = markov_chain(dave_chappelle)
kevin_dict = markov_chain(kevin_hart)

# Generate sentences for each comedian
dave_sentence = generate_sentence(dave_dict)
kevin_sentence = generate_sentence(kevin_dict)

print("Dave Chappelle's sentence:", dave_sentence)
print("Kevin Hart's sentence:", kevin_sentence)
# Out:
# Dave Chappelle's sentence: Round and pulled the music. Music started blasting from Bad Boy Records jumped back and.
# Kevin Hart's sentence: Everybody, say it’s not gonna have been. Always have asked. Carlton from a higher level.

# %%
# Generate sentences for all comedians
for comedian in data.index:
    transcript = data.transcript.loc[comedian]
    chain = markov_chain(transcript)
    sentence = generate_sentence(chain)
    print(f"{comedian.capitalize()}'s sentence:", sentence)
# Out:
# Adel_karam's sentence: Tightly and walking next to Abo Dani, and the wall. What’s cool is that?” I.
# Amy_schumer's sentence: And as I was a gymnast. I just paid me real rape-y all the road,.
# Beth_stelling's sentence: Shoulder height. That’s a happy ending situation. You know if I don’t know better, I’m.
# Big_jay_oakerson's sentence: “just gorgeous athletes.” That’s serious as it all costs. And then pull out, and he.
# Chelsea_handler's sentence: Research and I need to get in, a doctor’s office and then they get empathy?.
# Chris_rock's sentence: Diss. I love about abortion, you can Venmo me.” What, ’cause her a baby. ‘Cause.
# Dave_chappelle's sentence: [exhales] of the trailer. “What do a homeless guy, this n*gga had a very powerful.
# David_cross's sentence: Emotional level. That’s the solution was jerking off your facial hair? Fuck that. Huh? Wait,.
# Dylan_moran's sentence: Cat, “ha ha ha ha ha!” It’s like over me, yeah. “Where do you must.
# George_carlin's sentence: ’em the fort. However, Limping Ox. However, Limping Ox. However, Limping Ox is your list.
# Iliza_shlesinger's sentence: Watched the way to extract your makeup done it, Nashville turned on this practice. A.
# Kevin_hart's sentence: Doing? Good? [crowd applauding] Forty-one. What the toilet that I dropped the water and shit..
# Kevin_james's sentence: Car last night, sir. [audience whoops] Nothing. We are… You know, so we go.” He.
# Louis_c_k's sentence: Yeah, take it in the flash. That’s what I ate the guy’s like, “Yes.” So,.
# Matt_rife's sentence: Fine line up all on steroids, you could get cancelable. Let’s do you so, so.
# Pete_davidson's sentence: Drives off, all fucking hurt. That’s thoughtful. One of this been friends with my God..
# Ricky_gervais's sentence: Bag of God.” Just a true actually. I’ve hurt my anger, but my plane and.
# Sarah_cooper's sentence: Seen. They are we want to. [heart beating] The Donald has to be okay ♪.
# Tom_segura's sentence: Won the bank. Is he does. There’s another book for a grown man. And she’s.
# Trevor_noah's sentence: Jedi.” [in German accent] “Which Hitler?” “Which Hitler?” I had a public bathroom, you’re loyal..

# %% [markdown]
# ### Assignment 2 To improve the generate_sentence function, we can modify it to end with a random punctuation mark or end whenever it encounters a word that already ends with a punctuation mark. Here's the updated version of the function:

# %%
import random
import string

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''
    
    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        # Check if the word ends with punctuation
        if word1[-1] in string.punctuation:
            # End the sentence if it ends with punctuation
            break
        else:
            # Continue generating the sentence
            word2 = random.choice(chain[word1])
            word1 = word2
            sentence += ' ' + word2

    # End it with a period or a random punctuation mark if it doesn't already end with punctuation
    if sentence[-1] not in string.punctuation:
        sentence += random.choice(string.punctuation)
    else:
        sentence += random.choice(string.punctuation.replace(sentence[-1], ''))
    
    return sentence
# Out:
# 'You’re in slavery like my car?” “I want likes.:'

# %%
# Generate sentences for all comedians
for comedian in data.index:
    transcript = data.transcript.loc[comedian]
    chain = markov_chain(transcript)
    sentence = generate_sentence(chain)
    print(f"{comedian.capitalize()}'s sentence:", sentence)
# Out:
# Adel_karam's sentence: Sell you from?&
# Amy_schumer's sentence: Doesn’t matter what did it”.$
# Beth_stelling's sentence: Relationships.>
# Big_jay_oakerson's sentence: Take me come over to take dick touches the holidays and I ruined it!” Then,
# Chelsea_handler's sentence: Har… I stopped watching the little bit less fuckin’ wrong.~
# Chris_rock's sentence: Player to sneak back in horrible shape.~
# Dave_chappelle's sentence: Carolina.+
# David_cross's sentence: Qualifying what to do.+
# Dylan_moran's sentence: Pool of you,+
# George_carlin's sentence: Loft.>
# Iliza_shlesinger's sentence: In."
# Kevin_hart's sentence: 40?~
# Kevin_james's sentence: Theme is the thing.(
# Louis_c_k's sentence: Want,&
# Matt_rife's sentence: Check,.
# Pete_davidson's sentence: So the restraining order,'
# Ricky_gervais's sentence: Exuberance:}
# Sarah_cooper's sentence: And it’s safe.<
# Tom_segura's sentence: Good?.
# Trevor_noah's sentence: History.” You were talking about.#
